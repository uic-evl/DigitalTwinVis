# %%
import numpy as np
import pandas as pd
import torch
import re
pd.set_option('display.max_rows', 200)

# %%
class Const:
    data_dir = '../data'
    twin_data = data_dir + 'digital_twin_data.csv'
    twin_ln_data = data_dir + 'digital_twin_ln_data.csv'
    
    rename_dict = {
        'Dummy ID': 'id',
        'Age at Diagnosis (Calculated)': 'age',
        'Feeding tube 6m': 'FT',
        'Affected Lymph node UPPER': 'affected_nodes',
        'Aspiration rate(Y/N)': 'AS',
        'Neck boost (Y/N)': 'neck_boost',
        'Gender': 'gender',
        'Tm Laterality (R/L)': 'laterality',
        'AJCC 8th edition': 'ajcc8',
        'AJCC 7th edition':'ajcc7',
        'N_category_full': 'N-category',
        'HPV/P16 status': 'hpv',
        'Tumor subsite (BOT/Tonsil/Soft Palate/Pharyngeal wall/GPS/NOS)': 'subsite',
        'Total dose': 'total_dose',
        'Therapeutic combination': 'treatment',
        'Smoking status at Diagnosis (Never/Former/Current)': 'smoking_status',
        'Smoking status (Packs/Year)': 'packs_per_year',
        'Overall Survival (1=alive,0=dead)': 'os',
        'Dose/fraction (Gy)': 'dose_fraction'
    }
    
    dlt_dict = {
         'Allergic reaction to Cetuximab': 'DLT_Other',
         'Cardiological (A-fib)': 'DLT_Other',
         'Dermatological': 'DLT_Dermatological',
         'Failure to Thrive': 'DLT_Other',
         'Failure to thrive': 'DLT_Other',
         'GIT [elevated liver enzymes]': 'DLT_Gastrointestinal',
         'Gastrointestina': 'DLT_Gastrointestinal',
         'Gastrointestinal': 'DLT_Gastrointestinal',
         'General': 'DLT_Other',
         'Hematological': 'DLT_Hematological',
         'Hematological (Neutropenia)': 'DLT_Hematological',
         'Hyponatremia': 'DLT_Other',
         'Immunological': 'DLT_Other',
         'Infection': 'DLT_Infection (Pneumonia)',
         'NOS': 'DLT_Other',
         'Nephrological': 'DLT_Nephrological',
         'Nephrological (ARF)': 'DLT_Nephrological',
         'Neurological': 'DLT_Neurological',
         'Neutropenia': 'DLT_Hematological',
         'Nutritional': 'DLT_Other',
         'Pancreatitis': 'DLT_Other',
         'Pulmonary': 'DLT_Other',
         'Respiratory (Pneumonia)': 'DLT_Infection (Pneumonia)',
         'Sepsis': 'DLT_Infection (Pneumonia)',
         'Suboptimal response to treatment' : 'DLT_Other',
         'Vascular': 'DLT_Vascular'
    }
    
    decision1 = 'Decision 1 (Induction Chemo) Y/N'
    decision2 = 'Decision 2 (CC / RT alone)'
    decision3 = 'Decision 3 Neck Dissection (Y/N)'
    decisions = [decision1,decision2, decision3]
    outcomes = ['Overall Survival (4 Years)', 'FT', 'Aspiration rate Post-therapy']
    
    modification_types = {
        0: 'no_dose_adjustment',
        1: 'dose_modified',
        2: 'dose_delayed',
        3: 'dose_cancelled',
        4: 'dose_delayed_&_modified',
        5: 'regiment_modification',
        9: 'unknown'
    }
    
    cc_types = {
        0: 'cc_none',
        1: 'cc_platinum',
        2: 'cc_cetuximab',
        3: 'cc_others',
    }
    
    primary_disease_states = ['CR Primary','PR Primary','SD Primary']
    nodal_disease_states = [t.replace('Primary','Nodal') for t in primary_disease_states]
    dlt1 = list(set(dlt_dict.values()))
    
    modifications =  list(modification_types.values())
    state2 = modifications + primary_disease_states+nodal_disease_states +dlt1 #+['No imaging 0=N,1=Y']
    
    primary_disease_states2 = [t + ' 2' for t in primary_disease_states]
    nodal_disease_states2 = [t + ' 2' for t in nodal_disease_states]
    dlt2 = [d + ' 2' for d in dlt1]
    
    ccs = list(cc_types.values())
    state3 = ccs + primary_disease_states2 + nodal_disease_states2 + dlt2
    name_dict = {
        'pd_state1': primary_disease_states,
        'nd_state1': nodal_disease_states,
        'chemo_state1': modifications,
        'chemo_state2': ccs,
        'pd_state2': primary_disease_states2,
        'pd_state2': nodal_disease_states2,
    }
    
Const.primary_disease_states
# Out:
# ['CR Primary', 'PR Primary', 'SD Primary']

# %%
def preprocess(data_cleaned):
    #this was Elisa's preprocessing except I removed all the Ifs because that's dumb
    if len(data_cleaned.shape) < 2:
        data_cleaned = pd.DataFrame([data], columns=data.index)
        
    data_cleaned.loc[data_cleaned['Aspiration rate Pre-therapy'] == 'N', 'Aspiration rate Pre-therapy'] = 0
    data_cleaned.loc[data_cleaned['Aspiration rate Pre-therapy'] == 'Y', 'Aspiration rate Pre-therapy'] = 1

    data_cleaned.loc[data_cleaned['Pathological Grade'] == 'I', 'Pathological Grade'] = 1
    data_cleaned.loc[data_cleaned['Pathological Grade'] == 'II', 'Pathological Grade'] = 2
    data_cleaned.loc[data_cleaned['Pathological Grade'] == 'III', 'Pathological Grade'] = 3
    data_cleaned.loc[data_cleaned['Pathological Grade'] == 'IV', 'Pathological Grade'] = 4

    data_cleaned.loc[(data_cleaned['T-category'] == 'Tx') | (data_cleaned['T-category'] == 'Tis'), 'T-category'] = 1
    data_cleaned.loc[data_cleaned['T-category'] == 'T1', 'T-category'] = 1
    data_cleaned.loc[data_cleaned['T-category'] == 'T2', 'T-category'] = 2
    data_cleaned.loc[data_cleaned['T-category'] == 'T3', 'T-category'] = 3
    data_cleaned.loc[data_cleaned['T-category'] == 'T4', 'T-category'] = 4

    data_cleaned.loc[data_cleaned['N-category'] == 'N0', 'N-category'] = 0
    data_cleaned.loc[data_cleaned['N-category'] == 'N1', 'N-category'] = 1
    data_cleaned.loc[data_cleaned['N-category'] == 'N2', 'N-category'] = 2
    data_cleaned.loc[data_cleaned['N-category'] == 'N3', 'N-category'] = 3

    data_cleaned.loc[data_cleaned['N-category_8th_edition'] == 'N0', 'N-category_8th_edition'] = 0
    data_cleaned.loc[data_cleaned['N-category_8th_edition'] == 'N1', 'N-category_8th_edition'] = 1
    data_cleaned.loc[data_cleaned['N-category_8th_edition'] == 'N2', 'N-category_8th_edition'] = 2
    data_cleaned.loc[data_cleaned['N-category_8th_edition'] == 'N3', 'N-category_8th_edition'] = 3

    data_cleaned.loc[data_cleaned['AJCC 7th edition'] == 'I', 'AJCC 7th edition'] = 1
    data_cleaned.loc[data_cleaned['AJCC 7th edition'] == 'II', 'AJCC 7th edition'] = 2
    data_cleaned.loc[data_cleaned['AJCC 7th edition'] == 'III', 'AJCC 7th edition'] = 3
    data_cleaned.loc[data_cleaned['AJCC 7th edition'] == 'IV', 'AJCC 7th edition'] = 4

    data_cleaned.loc[data_cleaned['AJCC 8th edition'] == 'I', 'AJCC 8th edition'] = 1
    data_cleaned.loc[data_cleaned['AJCC 8th edition'] == 'II', 'AJCC 8th edition'] = 2
    data_cleaned.loc[data_cleaned['AJCC 8th edition'] == 'III', 'AJCC 8th edition'] = 3
    data_cleaned.loc[data_cleaned['AJCC 8th edition'] == 'IV', 'AJCC 8th edition'] = 4

    data_cleaned.loc[data_cleaned['Gender'] == 'Male', 'Gender'] = 1
    data_cleaned.loc[data_cleaned['Gender'] == 'Female', 'Gender'] = 0


    data_cleaned.loc[data_cleaned['HPV/P16 status'] == 'Positive', 'HPV/P16 status'] = 1
    data_cleaned.loc[data_cleaned['HPV/P16 status'] == 'Negative', 'HPV/P16 status'] = -1
    data_cleaned.loc[data_cleaned['HPV/P16 status'] == 'Unknown', 'HPV/P16 status'] = 0

    data_cleaned.loc[data_cleaned[
                         'Smoking status at Diagnosis (Never/Former/Current)'] == 'Formar', 'Smoking status at Diagnosis (Never/Former/Current)'] = .5
    data_cleaned.loc[data_cleaned[
                         'Smoking status at Diagnosis (Never/Former/Current)'] == 'Current', 'Smoking status at Diagnosis (Never/Former/Current)'] = 1
    data_cleaned.loc[data_cleaned[
                         'Smoking status at Diagnosis (Never/Former/Current)'] == 'Never', 'Smoking status at Diagnosis (Never/Former/Current)'] = 0


    data_cleaned.loc[data_cleaned['Chemo Modification (Y/N)'] == 'Y', 'Chemo Modification (Y/N)'] = 1

    data_cleaned.loc[data_cleaned['DLT (Y/N)'] == 'N', 'DLT (Y/N)'] = 0
    data_cleaned.loc[data_cleaned['DLT (Y/N)'] == 'Y', 'DLT (Y/N)'] = 1

    data_cleaned['DLT_Other'] = 0
    for index, row in data_cleaned.iterrows():
        if row['DLT_Type'] == 'None':
            continue
        for i in re.split('&|and|,', row['DLT_Type']):
            if i.strip() != '' and data_cleaned.loc[index, Const.dlt_dict[i.strip()]] == 0:
                data_cleaned.loc[index, Const.dlt_dict[i.strip()]] = 1

    data_cleaned.loc[data_cleaned['Decision 2 (CC / RT alone)'] == 'RT alone', 'Decision 2 (CC / RT alone)'] = 0
    data_cleaned.loc[data_cleaned['Decision 2 (CC / RT alone)'] == 'CC', 'Decision 2 (CC / RT alone)'] = 1

    data_cleaned.loc[data_cleaned['CC modification (Y/N)'] == 'N', 'CC modification (Y/N)'] = 0
    data_cleaned.loc[data_cleaned['CC modification (Y/N)'] == 'Y', 'CC modification (Y/N)'] = 1

    data_cleaned['DLT_Dermatological 2'] = 0
    data_cleaned['DLT_Neurological 2'] = 0
    data_cleaned['DLT_Gastrointestinal 2'] = 0
    data_cleaned['DLT_Hematological 2'] = 0
    data_cleaned['DLT_Nephrological 2'] = 0
    data_cleaned['DLT_Vascular 2'] = 0
    data_cleaned['DLT_Infection (Pneumonia) 2'] = 0
    data_cleaned['DLT_Other 2'] = 0
    for index, row in data_cleaned.iterrows():
        if row['DLT 2'] == 'None':
            continue
        for i in re.split('&|and|,', row['DLT 2']):
            if i.strip() != '':
                data_cleaned.loc[index, Const.dlt_dict[i.strip()] + ' 2'] = 1

    data_cleaned.loc[
        data_cleaned['Decision 3 Neck Dissection (Y/N)'] == 'N', 'Decision 3 Neck Dissection (Y/N)'] = 0
    data_cleaned.loc[
        data_cleaned['Decision 3 Neck Dissection (Y/N)'] == 'Y', 'Decision 3 Neck Dissection (Y/N)'] = 1

    return data_cleaned

def merge_editions(row,basecol='AJCC 8th edition',fallback='AJCC 7th edition'):
    if pd.isnull(row[basecol]):
        return row[fallback]
    return row[basecol]


def preprocess_dt_data(df,extra_to_keep=None):
    
    to_keep = ['id','hpv','age','packs_per_year','smoking_status','gender','Aspiration rate Pre-therapy','total_dose','dose_fraction'] 
    to_onehot = ['T-category','N-category','AJCC','Pathological Grade','subsite','treatment','ln_cluster']
    if extra_to_keep is not None:
        to_keep = to_keep + [c for c in extra_to_keep if c not in to_keep and c not in to_onehot]
    
    decisions =Const.decisions
    outcomes = Const.outcomes
    
    modification_types = {
        0: 'no_dose_adjustment',
        1: 'dose_modified',
        2: 'dose_delayed',
        3: 'dose_cancelled',
        4: 'dose_delayed_&_modified',
        5: 'regiment_modification',
        9: 'unknown'
    }
    
    cc_types = {
        0: 'cc_none',
        1: 'cc_platinum',
        2: 'cc_cetuximab',
        3: 'cc_others',
    }
    
    races_shortened = ['White/Caucasian','Hispanic/Latino','African American/Black']
    for race in races_shortened:
        df[race] = df['Race'].apply(lambda x: x.strip() == race)
        to_keep.append(race)
    
    for k,v in Const.cc_types.items():
        df[v] = df['CC Regimen(0= none, 1= platinum based, 2= cetuximab based, 3= others, 9=unknown)'].apply(lambda x: int(Const.cc_types.get(int(x),0) == v))
        to_keep.append(v)
    for k,v in Const.modification_types.items():
        name = 'Modification Type (0= no dose adjustment, 1=dose modified, 2=dose delayed, 3=dose cancelled, 4=dose delayed & modified, 5=regimen modification, 9=unknown)'
        df[v] = df[name].apply(lambda x: int(Const.modification_types.get(int(x),0) == v))
        to_keep.append(v)
    #Features to keep. I think gender is is in 
    
    keywords = []
    for keyword in keywords:
        toadd = [c for c in df.columns if keyword in c and c not in to_keep]
        to_keep = to_keep + toadd
    
    df['packs_per_year'] = df['packs_per_year'].apply(lambda x: str(x).replace('>','').replace('<','')).astype(float).fillna(0)
    #so I'm actually not sure if this is biological sex or gender given this is texas
    df['AJCC'] = df.apply(lambda row: merge_editions(row,'ajcc8','ajcc7'),axis=1)
    df['N-category'] = df.apply(lambda row: merge_editions(row,'N-category_8th_edition','N-category'),axis=1)
    
    dummy_df = pd.get_dummies(df[to_onehot].fillna(0).astype(str),drop_first=False)
    for col in dummy_df.columns:
        df[col] = dummy_df[col]
        to_keep.append(col)
        
    yn_to_binary = ['FT','Aspiration rate Post-therapy','Decision 1 (Induction Chemo) Y/N']
    for col in yn_to_binary:
        df[col] = df[col].apply(lambda x: int(x == 'Y'))
        
    to_keep = to_keep + [c for c in df.columns if 'DLT' in c]
    
    df['bilateral'] = df['Tm Laterality (R/L)'].apply(lambda x: x.lower().strip() == 'bilateral')
    to_keep.append('bilateral')
    
    for statelist in [Const.state2,Const.state3,Const.decisions,Const.outcomes]:
        toadd = [c for c in statelist if c not in to_keep]
        to_keep = to_keep + toadd
    return df[to_keep].set_index('id')

# %%
def load_digital_twin(file='../data/digital_twin_data.csv'):
    df = pd.read_csv(file)
    return df.rename(columns = Const.rename_dict)

def get_dt_ids():
    df = load_digital_twin()
    return df.id.values
get_dt_ids()
# Out:
# /tmp/ipykernel_2197865/1992661605.py:2: DtypeWarning: Columns (55) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# array([    3,     5,     6,     7,     8,     9,    10,    11,    13,
#           14,    15,    16,    17,    18,    21,    23,    24,    25,
#           26,    27,    28,    31,    32,    33,    35,    36,    37,
#           38,    39,    40,    41,    42,    44,    45,    47,    48,
#           49,    50,    51,    53,    55,    56,    57,    60,    64,
#           65,    67,    68,    69,    71,    74,    75,    77,    78,
#           79,    80,    81,    82,    87,    88,    91,    94,    96,
#           99,   103,   109,   116,   117,   119,   120,   121,   125,
#          133,   148,   150,   153,   168,   178,   181,   183,   184,
#          185,   186,   187,   188,   189,   190,   191,   192,   193,
#          194,   195,   196,   197,   198,   199,   200,   201,   202,
#          203,   204,   205,   206,   207,   208,   209,   210,   211,
#          212,   213,   214,   215,   216,   217,   218,   219,   220,
#          221,   222,   223,   224,   225,   226,   227,   228,   229,
#          230,   231,   232,   233,   234,   235,   236,   237,   238,
#          239,   240,   241,   242,   243,   244,   245,   246,   247,
#          248,   249,   251,   252,   253,   254,   255,   256,   257,
#          258,   259,   260,   261,   262,   263,   264,   265,   266,
#          267,   268,   269,   270,   271,   272,   273,   274,   275,
#          276,   277,   278,   279,   280,   281,   282,   283,   284,
#          285,   286,   287,   288,   289,  2000,  2001,  2002,  2003,
#         2004,  2005,  2006,  2007,  2008,  2009,  2010,  2011,  2012,
#         2013,  2014,  2015,  2016,  2017,  2018,  2019,  2020,  2021,
#         2022,  2023,  2024,  2025,  2026,  2027,  2028,  2029,  2030,
#         2031,  2032,  2033,  5000,  5001,  5002,  5003,  5004,  5005,
#         5006,  5007,  5008,  5009,  5010,  5011,  5012,  5013,  5014,
#         5015,  5016,  5017,  5018,  5019,  5020,  5021,  5022,  5023,
#         5024,  5025,  5026,  5027,  5028,  5029,  5030,  5031,  5032,
#         5033,  5034,  5035,  5036,  5037,  5038,  5039,  5040,  5041,
#         5042,  5043,  5044,  5045,  5047,  5048,  5049,  5050,  5051,
#         5052,  5053,  5054,  5055,  5056,  5057,  5058,  5059,  5060,
#         5061,  5062,  5063,  5064,  5065,  5066,  5067,  5068,  5069,
#         5070,  5071,  5072,  5073,  5074,  5075,  5076,  5077,  5078,
#         5079,  5080,  5081,  5082,  5083,  5084,  5085,  5086,  5087,
#         5088,  5089,  5090,  5091,  5092,  5093,  5094,  5095,  5096,
#         5097,  5098,  5099,  5100,  5101,  5102,  5103,  5104,  5105,
#         5106,  5107,  5108,  5109,  5110,  5111,  5112,  5113,  5114,
#         5115,  5117,  5118,  5119,  5120, 10001, 10002, 10003, 10004,
#        10005, 10006, 10007, 10008, 10009, 10010, 10011, 10012, 10013,
#        10014, 10015, 10016, 10017, 10018, 10019, 10020, 10021, 10022,
#        10023, 10024, 10025, 10026, 10027, 10028, 10029, 10031, 10033,
#        10034, 10035, 10036, 10037, 10038, 10039, 10040, 10041, 10042,
#        10043, 10044, 10045, 10046, 10047, 10048, 10049, 10050, 10051,
#        10052, 10053, 10054, 10055, 10056, 10057, 10058, 10059, 10060,
#        10061, 10062, 10063, 10064, 10065, 10066, 10067, 10068, 10069,
#        10070, 10071, 10072, 10073, 10074, 10075, 10077, 10078, 10079,
#        10080, 10081, 10082, 10083, 10084, 10085, 10086, 10087, 10088,
#        10089, 10090, 10091, 10092, 10093, 10094, 10095, 10096, 10097,
#        10098, 10099, 10100, 10101, 10102, 10103, 10104, 10105, 10106,
#        10107, 10108, 10109, 10110, 10111, 10113, 10114, 10115, 10116,
#        10117, 10118, 10119, 10120, 10121, 10123, 10124, 10125, 10126,
#        10127, 10128, 10129, 10130, 10131, 10132, 10133, 10134, 10135,
#        10136, 10137, 10138, 10139, 10140, 10141, 10142, 10143, 10144,
#        10145, 10146, 10147, 10148, 10149, 10150, 10151, 10152, 10153,
#        10154, 10155, 10156, 10157, 10158, 10159, 10160, 10161, 10162,
#        10163, 10164, 10165, 10167, 10168, 10169, 10170, 10171, 10172,
#        10173, 10174, 10175, 10176, 10177, 10178, 10180, 10181, 10182,
#        10183, 10184, 10185, 10186, 10187, 10188, 10189, 10190, 10191,
#        10192, 10193, 10194, 10195, 10196, 10197, 10198, 10199, 10200,
#        10201, 10202, 10203, 10204, 10205])

# %%
for c in pd.read_csv('../data/digital_twin_data.csv').columns:
    print(c)
# Out:
# MRN OPC
# Dummy ID
# Therapeutic combination
# Decision 1 (Induction Chemo) Y/N
# Prescribed Chemo (Single/doublet/triplet/quadruplet/none/NOS)
# Chemo Modification (Y/N)
# Modification Type (0= no dose adjustment, 1=dose modified, 2=dose delayed, 3=dose cancelled, 4=dose delayed & modified, 5=regimen modification, 9=unknown)
# DLT (Y/N)
# DLT_Type
# DLT_Dermatological
# DLT_Neurological
# DLT_Gastrointestinal
# DLT_Hematological
# DLT_Nephrological
# DLT_Vascular
# DLT_Infection (Pneumonia)
# DLT_Grade
# No imaging (0=N, 1=Y)
# CR Primary
# CR Nodal
# PR Primary
# PR Nodal
# SD Primary
# SD Nodal
# PD Primary
# PD Nodal
# Decision 2 (CC / RT alone)
# CC Regimen(0= none, 1= platinum based, 2= cetuximab based, 3= others, 9=unknown)
# DLT 2
# CC modification (Y/N)
# CR Primary 2
# CR Nodal 2
# PR Primary 2
# PR Nodal 2
# SD Primary 2
# SD Nodal 2
# Decision 3 Neck Dissection (Y/N)
# Neck Dissection_Pathology
# Neck Disssection after IMRT (Y/N)
# Neck Dissection after IMRT (Y / levels)
# Age at Diagnosis (Calculated)
# Pathological Grade
# Gender
# Race
# Tm Laterality (R/L)
# Tumor subsite (BOT/Tonsil/Soft Palate/Pharyngeal wall/GPS/NOS)
# HPV/P16 status
# Affected Lymph node
# Affected Lymph node cleaned
# T-category
# N-category
# N-category_8th_edition
# AJCC 7th edition
# AJCC 8th edition
# Smoking status at Diagnosis (Never/Former/Current)
# Smoking status (Packs/Year)
# Neck boost (Y/N)
# Overall Survival (1=alive, 0=dead)
# Local Control (1=no control, 0=primary recurrance)
# Regional Control (1=regional/nodal control,0=regional/nodal recurrance)
# Locoregional Control(1=Control,0=Failure)
# Distant Control (1=no DM, 0=DM)
# OS (Calculated)
# Regional control (Time)
# Local control (Time)
# Locoregional control (Time)
# FDM (months)
# Total dose
# Total fractions
# Treatment duration (Days)
# Dose/fraction (Gy)
# Feeding tube 6m
# Aspiration rate Pre-therapy
# Aspiration rate Post-therapy
# Aspiration rate(Y/N)
# Aspiration type
# ROI
# F2-GrayLevelCooccurenceMatrix25-333-1AutoCorrelation
# F2-GrayLevelCooccurenceMatrix25-333-2AutoCorrelation
# F2-GrayLevelCooccurenceMatrix25-333-3AutoCorrelation
# F2-GrayLevelCooccurenceMatrix25-333-4AutoCorrelation
# F2-GrayLevelCooccurenceMatrix25-333-5AutoCorrelation
# F2-GrayLevelCooccurenceMatrix25-333-6AutoCorrelation
# F2-GrayLevelCooccurenceMatrix25-333-7AutoCorrelation
# F2-GrayLevelCooccurenceMatrix250-1AutoCorrelation
# F2-GrayLevelCooccurenceMatrix250-2AutoCorrelation
# F2-GrayLevelCooccurenceMatrix250-3AutoCorrelation
# F2-GrayLevelCooccurenceMatrix250-4AutoCorrelation
# F2-GrayLevelCooccurenceMatrix250-5AutoCorrelation
# F2-GrayLevelCooccurenceMatrix250-6AutoCorrelation
# F2-GrayLevelCooccurenceMatrix250-7AutoCorrelation
# F2-GrayLevelCooccurenceMatrix2545-1AutoCorrelation
# F2-GrayLevelCooccurenceMatrix2545-2AutoCorrelation
# F2-GrayLevelCooccurenceMatrix2545-3AutoCorrelation
# F2-GrayLevelCooccurenceMatrix2545-4AutoCorrelation
# F2-GrayLevelCooccurenceMatrix2545-5AutoCorrelation
# F2-GrayLevelCooccurenceMatrix2545-6AutoCorrelation
# F2-GrayLevelCooccurenceMatrix2545-7AutoCorrelation
# F2-GrayLevelCooccurenceMatrix2590-1AutoCorrelation
# F2-GrayLevelCooccurenceMatrix2590-2AutoCorrelation
# F2-GrayLevelCooccurenceMatrix2590-3AutoCorrelation
# F2-GrayLevelCooccurenceMatrix2590-4AutoCorrelation
# F2-GrayLevelCooccurenceMatrix2590-5AutoCorrelation
# F2-GrayLevelCooccurenceMatrix2590-6AutoCorrelation
# F2-GrayLevelCooccurenceMatrix2590-7AutoCorrelation
# F2-GrayLevelCooccurenceMatrix25135-1AutoCorrelation
# F2-GrayLevelCooccurenceMatrix25135-2AutoCorrelation
# F2-GrayLevelCooccurenceMatrix25135-3AutoCorrelation
# F2-GrayLevelCooccurenceMatrix25135-4AutoCorrelation
# F2-GrayLevelCooccurenceMatrix25135-5AutoCorrelation
# F2-GrayLevelCooccurenceMatrix25135-6AutoCorrelation
# F2-GrayLevelCooccurenceMatrix25135-7AutoCorrelation
# F2-GrayLevelCooccurenceMatrix25180-1AutoCorrelation
# F2-GrayLevelCooccurenceMatrix25180-2AutoCorrelation
# F2-GrayLevelCooccurenceMatrix25180-3AutoCorrelation
# F2-GrayLevelCooccurenceMatrix25180-4AutoCorrelation
# F2-GrayLevelCooccurenceMatrix25180-5AutoCorrelation
# F2-GrayLevelCooccurenceMatrix25180-6AutoCorrelation
# F2-GrayLevelCooccurenceMatrix25180-7AutoCorrelation
# F2-GrayLevelCooccurenceMatrix25225-1AutoCorrelation
# F2-GrayLevelCooccurenceMatrix25225-2AutoCorrelation
# F2-GrayLevelCooccurenceMatrix25225-3AutoCorrelation
# F2-GrayLevelCooccurenceMatrix25225-4AutoCorrelation
# F2-GrayLevelCooccurenceMatrix25225-5AutoCorrelation
# F2-GrayLevelCooccurenceMatrix25225-6AutoCorrelation
# F2-GrayLevelCooccurenceMatrix25225-7AutoCorrelation
# F2-GrayLevelCooccurenceMatrix25270-1AutoCorrelation
# F2-GrayLevelCooccurenceMatrix25270-2AutoCorrelation
# F2-GrayLevelCooccurenceMatrix25270-3AutoCorrelation
# F2-GrayLevelCooccurenceMatrix25270-4AutoCorrelation
# F2-GrayLevelCooccurenceMatrix25270-5AutoCorrelation
# F2-GrayLevelCooccurenceMatrix25270-6AutoCorrelation
# F2-GrayLevelCooccurenceMatrix25270-7AutoCorrelation
# F2-GrayLevelCooccurenceMatrix25315-1AutoCorrelation
# F2-GrayLevelCooccurenceMatrix25315-2AutoCorrelation
# F2-GrayLevelCooccurenceMatrix25315-3AutoCorrelation
# F2-GrayLevelCooccurenceMatrix25315-4AutoCorrelation
# F2-GrayLevelCooccurenceMatrix25315-5AutoCorrelation
# F2-GrayLevelCooccurenceMatrix25315-6AutoCorrelation
# F2-GrayLevelCooccurenceMatrix25315-7AutoCorrelation
# F2-GrayLevelCooccurenceMatrix25-333-1ClusterProminence
# F2-GrayLevelCooccurenceMatrix25-333-2ClusterProminence
# F2-GrayLevelCooccurenceMatrix25-333-3ClusterProminence
# F2-GrayLevelCooccurenceMatrix25-333-4ClusterProminence
# F2-GrayLevelCooccurenceMatrix25-333-5ClusterProminence
# F2-GrayLevelCooccurenceMatrix25-333-6ClusterProminence
# F2-GrayLevelCooccurenceMatrix25-333-7ClusterProminence
# F2-GrayLevelCooccurenceMatrix250-1ClusterProminence
# F2-GrayLevelCooccurenceMatrix250-2ClusterProminence
# F2-GrayLevelCooccurenceMatrix250-3ClusterProminence
# F2-GrayLevelCooccurenceMatrix250-4ClusterProminence
# F2-GrayLevelCooccurenceMatrix250-5ClusterProminence
# F2-GrayLevelCooccurenceMatrix250-6ClusterProminence
# F2-GrayLevelCooccurenceMatrix250-7ClusterProminence
# F2-GrayLevelCooccurenceMatrix2545-1ClusterProminence
# F2-GrayLevelCooccurenceMatrix2545-2ClusterProminence
# F2-GrayLevelCooccurenceMatrix2545-3ClusterProminence
# F2-GrayLevelCooccurenceMatrix2545-4ClusterProminence
# F2-GrayLevelCooccurenceMatrix2545-5ClusterProminence
# F2-GrayLevelCooccurenceMatrix2545-6ClusterProminence
# F2-GrayLevelCooccurenceMatrix2545-7ClusterProminence
# F2-GrayLevelCooccurenceMatrix2590-1ClusterProminence
# F2-GrayLevelCooccurenceMatrix2590-2ClusterProminence
# F2-GrayLevelCooccurenceMatrix2590-3ClusterProminence
# F2-GrayLevelCooccurenceMatrix2590-4ClusterProminence
# F2-GrayLevelCooccurenceMatrix2590-5ClusterProminence
# F2-GrayLevelCooccurenceMatrix2590-6ClusterProminence
# F2-GrayLevelCooccurenceMatrix2590-7ClusterProminence
# F2-GrayLevelCooccurenceMatrix25135-1ClusterProminence
# F2-GrayLevelCooccurenceMatrix25135-2ClusterProminence
# F2-GrayLevelCooccurenceMatrix25135-3ClusterProminence
# F2-GrayLevelCooccurenceMatrix25135-4ClusterProminence
# F2-GrayLevelCooccurenceMatrix25135-5ClusterProminence
# F2-GrayLevelCooccurenceMatrix25135-6ClusterProminence
# F2-GrayLevelCooccurenceMatrix25135-7ClusterProminence
# F2-GrayLevelCooccurenceMatrix25180-1ClusterProminence
# F2-GrayLevelCooccurenceMatrix25180-2ClusterProminence
# F2-GrayLevelCooccurenceMatrix25180-3ClusterProminence
# F2-GrayLevelCooccurenceMatrix25180-4ClusterProminence
# F2-GrayLevelCooccurenceMatrix25180-5ClusterProminence
# F2-GrayLevelCooccurenceMatrix25180-6ClusterProminence
# F2-GrayLevelCooccurenceMatrix25180-7ClusterProminence
# F2-GrayLevelCooccurenceMatrix25225-1ClusterProminence
# F2-GrayLevelCooccurenceMatrix25225-2ClusterProminence
# F2-GrayLevelCooccurenceMatrix25225-3ClusterProminence
# F2-GrayLevelCooccurenceMatrix25225-4ClusterProminence
# F2-GrayLevelCooccurenceMatrix25225-5ClusterProminence
# F2-GrayLevelCooccurenceMatrix25225-6ClusterProminence
# F2-GrayLevelCooccurenceMatrix25225-7ClusterProminence
# F2-GrayLevelCooccurenceMatrix25270-1ClusterProminence
# F2-GrayLevelCooccurenceMatrix25270-2ClusterProminence
# F2-GrayLevelCooccurenceMatrix25270-3ClusterProminence
# F2-GrayLevelCooccurenceMatrix25270-4ClusterProminence
# F2-GrayLevelCooccurenceMatrix25270-5ClusterProminence
# F2-GrayLevelCooccurenceMatrix25270-6ClusterProminence
# F2-GrayLevelCooccurenceMatrix25270-7ClusterProminence
# F2-GrayLevelCooccurenceMatrix25315-1ClusterProminence
# F2-GrayLevelCooccurenceMatrix25315-2ClusterProminence
# F2-GrayLevelCooccurenceMatrix25315-3ClusterProminence
# F2-GrayLevelCooccurenceMatrix25315-4ClusterProminence
# F2-GrayLevelCooccurenceMatrix25315-5ClusterProminence
# F2-GrayLevelCooccurenceMatrix25315-6ClusterProminence
# F2-GrayLevelCooccurenceMatrix25315-7ClusterProminence
# F2-GrayLevelCooccurenceMatrix25-333-1ClusterShade
# F2-GrayLevelCooccurenceMatrix25-333-2ClusterShade
# F2-GrayLevelCooccurenceMatrix25-333-3ClusterShade
# F2-GrayLevelCooccurenceMatrix25-333-4ClusterShade
# F2-GrayLevelCooccurenceMatrix25-333-5ClusterShade
# F2-GrayLevelCooccurenceMatrix25-333-6ClusterShade
# F2-GrayLevelCooccurenceMatrix25-333-7ClusterShade
# F2-GrayLevelCooccurenceMatrix250-1ClusterShade
# F2-GrayLevelCooccurenceMatrix250-2ClusterShade
# F2-GrayLevelCooccurenceMatrix250-3ClusterShade
# F2-GrayLevelCooccurenceMatrix250-4ClusterShade
# F2-GrayLevelCooccurenceMatrix250-5ClusterShade
# F2-GrayLevelCooccurenceMatrix250-6ClusterShade
# F2-GrayLevelCooccurenceMatrix250-7ClusterShade
# F2-GrayLevelCooccurenceMatrix2545-1ClusterShade
# F2-GrayLevelCooccurenceMatrix2545-2ClusterShade
# F2-GrayLevelCooccurenceMatrix2545-3ClusterShade
# F2-GrayLevelCooccurenceMatrix2545-4ClusterShade
# F2-GrayLevelCooccurenceMatrix2545-5ClusterShade
# F2-GrayLevelCooccurenceMatrix2545-6ClusterShade
# F2-GrayLevelCooccurenceMatrix2545-7ClusterShade
# F2-GrayLevelCooccurenceMatrix2590-1ClusterShade
# F2-GrayLevelCooccurenceMatrix2590-2ClusterShade
# F2-GrayLevelCooccurenceMatrix2590-3ClusterShade
# F2-GrayLevelCooccurenceMatrix2590-4ClusterShade
# F2-GrayLevelCooccurenceMatrix2590-5ClusterShade
# F2-GrayLevelCooccurenceMatrix2590-6ClusterShade
# F2-GrayLevelCooccurenceMatrix2590-7ClusterShade
# F2-GrayLevelCooccurenceMatrix25135-1ClusterShade
# F2-GrayLevelCooccurenceMatrix25135-2ClusterShade
# F2-GrayLevelCooccurenceMatrix25135-3ClusterShade
# F2-GrayLevelCooccurenceMatrix25135-4ClusterShade
# F2-GrayLevelCooccurenceMatrix25135-5ClusterShade
# F2-GrayLevelCooccurenceMatrix25135-6ClusterShade
# F2-GrayLevelCooccurenceMatrix25135-7ClusterShade
# F2-GrayLevelCooccurenceMatrix25180-1ClusterShade
# F2-GrayLevelCooccurenceMatrix25180-2ClusterShade
# F2-GrayLevelCooccurenceMatrix25180-3ClusterShade
# F2-GrayLevelCooccurenceMatrix25180-4ClusterShade
# F2-GrayLevelCooccurenceMatrix25180-5ClusterShade
# F2-GrayLevelCooccurenceMatrix25180-6ClusterShade
# F2-GrayLevelCooccurenceMatrix25180-7ClusterShade
# F2-GrayLevelCooccurenceMatrix25225-1ClusterShade
# F2-GrayLevelCooccurenceMatrix25225-2ClusterShade
# F2-GrayLevelCooccurenceMatrix25225-3ClusterShade
# F2-GrayLevelCooccurenceMatrix25225-4ClusterShade
# F2-GrayLevelCooccurenceMatrix25225-5ClusterShade
# F2-GrayLevelCooccurenceMatrix25225-6ClusterShade
# F2-GrayLevelCooccurenceMatrix25225-7ClusterShade
# F2-GrayLevelCooccurenceMatrix25270-1ClusterShade
# F2-GrayLevelCooccurenceMatrix25270-2ClusterShade
# F2-GrayLevelCooccurenceMatrix25270-3ClusterShade
# F2-GrayLevelCooccurenceMatrix25270-4ClusterShade
# F2-GrayLevelCooccurenceMatrix25270-5ClusterShade
# F2-GrayLevelCooccurenceMatrix25270-6ClusterShade
# F2-GrayLevelCooccurenceMatrix25270-7ClusterShade
# F2-GrayLevelCooccurenceMatrix25315-1ClusterShade
# F2-GrayLevelCooccurenceMatrix25315-2ClusterShade
# F2-GrayLevelCooccurenceMatrix25315-3ClusterShade
# F2-GrayLevelCooccurenceMatrix25315-4ClusterShade
# F2-GrayLevelCooccurenceMatrix25315-5ClusterShade
# F2-GrayLevelCooccurenceMatrix25315-6ClusterShade
# F2-GrayLevelCooccurenceMatrix25315-7ClusterShade
# F2-GrayLevelCooccurenceMatrix25-333-1ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix25-333-2ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix25-333-3ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix25-333-4ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix25-333-5ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix25-333-6ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix25-333-7ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix250-1ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix250-2ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix250-3ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix250-4ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix250-5ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix250-6ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix250-7ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix2545-1ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix2545-2ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix2545-3ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix2545-4ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix2545-5ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix2545-6ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix2545-7ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix2590-1ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix2590-2ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix2590-3ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix2590-4ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix2590-5ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix2590-6ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix2590-7ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix25135-1ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix25135-2ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix25135-3ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix25135-4ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix25135-5ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix25135-6ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix25135-7ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix25180-1ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix25180-2ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix25180-3ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix25180-4ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix25180-5ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix25180-6ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix25180-7ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix25225-1ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix25225-2ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix25225-3ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix25225-4ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix25225-5ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix25225-6ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix25225-7ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix25270-1ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix25270-2ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix25270-3ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix25270-4ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix25270-5ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix25270-6ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix25270-7ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix25315-1ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix25315-2ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix25315-3ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix25315-4ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix25315-5ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix25315-6ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix25315-7ClusterTendendcy
# F2-GrayLevelCooccurenceMatrix25-333-1Contrast
# F2-GrayLevelCooccurenceMatrix25-333-2Contrast
# F2-GrayLevelCooccurenceMatrix25-333-3Contrast
# F2-GrayLevelCooccurenceMatrix25-333-4Contrast
# F2-GrayLevelCooccurenceMatrix25-333-5Contrast
# F2-GrayLevelCooccurenceMatrix25-333-6Contrast
# F2-GrayLevelCooccurenceMatrix25-333-7Contrast
# F2-GrayLevelCooccurenceMatrix250-1Contrast
# F2-GrayLevelCooccurenceMatrix250-2Contrast
# F2-GrayLevelCooccurenceMatrix250-3Contrast
# F2-GrayLevelCooccurenceMatrix250-4Contrast
# F2-GrayLevelCooccurenceMatrix250-5Contrast
# F2-GrayLevelCooccurenceMatrix250-6Contrast
# F2-GrayLevelCooccurenceMatrix250-7Contrast
# F2-GrayLevelCooccurenceMatrix2545-1Contrast
# F2-GrayLevelCooccurenceMatrix2545-2Contrast
# F2-GrayLevelCooccurenceMatrix2545-3Contrast
# F2-GrayLevelCooccurenceMatrix2545-4Contrast
# F2-GrayLevelCooccurenceMatrix2545-5Contrast
# F2-GrayLevelCooccurenceMatrix2545-6Contrast
# F2-GrayLevelCooccurenceMatrix2545-7Contrast
# F2-GrayLevelCooccurenceMatrix2590-1Contrast
# F2-GrayLevelCooccurenceMatrix2590-2Contrast
# F2-GrayLevelCooccurenceMatrix2590-3Contrast
# F2-GrayLevelCooccurenceMatrix2590-4Contrast
# F2-GrayLevelCooccurenceMatrix2590-5Contrast
# F2-GrayLevelCooccurenceMatrix2590-6Contrast
# F2-GrayLevelCooccurenceMatrix2590-7Contrast
# F2-GrayLevelCooccurenceMatrix25135-1Contrast
# F2-GrayLevelCooccurenceMatrix25135-2Contrast
# F2-GrayLevelCooccurenceMatrix25135-3Contrast
# F2-GrayLevelCooccurenceMatrix25135-4Contrast
# F2-GrayLevelCooccurenceMatrix25135-5Contrast
# F2-GrayLevelCooccurenceMatrix25135-6Contrast
# F2-GrayLevelCooccurenceMatrix25135-7Contrast
# F2-GrayLevelCooccurenceMatrix25180-1Contrast
# F2-GrayLevelCooccurenceMatrix25180-2Contrast
# F2-GrayLevelCooccurenceMatrix25180-3Contrast
# F2-GrayLevelCooccurenceMatrix25180-4Contrast
# F2-GrayLevelCooccurenceMatrix25180-5Contrast
# F2-GrayLevelCooccurenceMatrix25180-6Contrast
# F2-GrayLevelCooccurenceMatrix25180-7Contrast
# F2-GrayLevelCooccurenceMatrix25225-1Contrast
# F2-GrayLevelCooccurenceMatrix25225-2Contrast
# F2-GrayLevelCooccurenceMatrix25225-3Contrast
# F2-GrayLevelCooccurenceMatrix25225-4Contrast
# F2-GrayLevelCooccurenceMatrix25225-5Contrast
# F2-GrayLevelCooccurenceMatrix25225-6Contrast
# F2-GrayLevelCooccurenceMatrix25225-7Contrast
# F2-GrayLevelCooccurenceMatrix25270-1Contrast
# F2-GrayLevelCooccurenceMatrix25270-2Contrast
# F2-GrayLevelCooccurenceMatrix25270-3Contrast
# F2-GrayLevelCooccurenceMatrix25270-4Contrast
# F2-GrayLevelCooccurenceMatrix25270-5Contrast
# F2-GrayLevelCooccurenceMatrix25270-6Contrast
# F2-GrayLevelCooccurenceMatrix25270-7Contrast
# F2-GrayLevelCooccurenceMatrix25315-1Contrast
# F2-GrayLevelCooccurenceMatrix25315-2Contrast
# F2-GrayLevelCooccurenceMatrix25315-3Contrast
# F2-GrayLevelCooccurenceMatrix25315-4Contrast
# F2-GrayLevelCooccurenceMatrix25315-5Contrast
# F2-GrayLevelCooccurenceMatrix25315-6Contrast
# F2-GrayLevelCooccurenceMatrix25315-7Contrast
# F2-GrayLevelCooccurenceMatrix25-333-1Correlation
# F2-GrayLevelCooccurenceMatrix25-333-2Correlation
# F2-GrayLevelCooccurenceMatrix25-333-3Correlation
# F2-GrayLevelCooccurenceMatrix25-333-4Correlation
# F2-GrayLevelCooccurenceMatrix25-333-5Correlation
# F2-GrayLevelCooccurenceMatrix25-333-6Correlation
# F2-GrayLevelCooccurenceMatrix25-333-7Correlation
# F2-GrayLevelCooccurenceMatrix250-1Correlation
# F2-GrayLevelCooccurenceMatrix250-2Correlation
# F2-GrayLevelCooccurenceMatrix250-3Correlation
# F2-GrayLevelCooccurenceMatrix250-4Correlation
# F2-GrayLevelCooccurenceMatrix250-5Correlation
# F2-GrayLevelCooccurenceMatrix250-6Correlation
# F2-GrayLevelCooccurenceMatrix250-7Correlation
# F2-GrayLevelCooccurenceMatrix2545-1Correlation
# F2-GrayLevelCooccurenceMatrix2545-2Correlation
# F2-GrayLevelCooccurenceMatrix2545-3Correlation
# F2-GrayLevelCooccurenceMatrix2545-4Correlation
# F2-GrayLevelCooccurenceMatrix2545-5Correlation
# F2-GrayLevelCooccurenceMatrix2545-6Correlation
# F2-GrayLevelCooccurenceMatrix2545-7Correlation
# F2-GrayLevelCooccurenceMatrix2590-1Correlation
# F2-GrayLevelCooccurenceMatrix2590-2Correlation
# F2-GrayLevelCooccurenceMatrix2590-3Correlation
# F2-GrayLevelCooccurenceMatrix2590-4Correlation
# F2-GrayLevelCooccurenceMatrix2590-5Correlation
# F2-GrayLevelCooccurenceMatrix2590-6Correlation
# F2-GrayLevelCooccurenceMatrix2590-7Correlation
# F2-GrayLevelCooccurenceMatrix25135-1Correlation
# F2-GrayLevelCooccurenceMatrix25135-2Correlation
# F2-GrayLevelCooccurenceMatrix25135-3Correlation
# F2-GrayLevelCooccurenceMatrix25135-4Correlation
# F2-GrayLevelCooccurenceMatrix25135-5Correlation
# F2-GrayLevelCooccurenceMatrix25135-6Correlation
# F2-GrayLevelCooccurenceMatrix25135-7Correlation
# F2-GrayLevelCooccurenceMatrix25180-1Correlation
# F2-GrayLevelCooccurenceMatrix25180-2Correlation
# F2-GrayLevelCooccurenceMatrix25180-3Correlation
# F2-GrayLevelCooccurenceMatrix25180-4Correlation
# F2-GrayLevelCooccurenceMatrix25180-5Correlation
# F2-GrayLevelCooccurenceMatrix25180-6Correlation
# F2-GrayLevelCooccurenceMatrix25180-7Correlation
# F2-GrayLevelCooccurenceMatrix25225-1Correlation
# F2-GrayLevelCooccurenceMatrix25225-2Correlation
# F2-GrayLevelCooccurenceMatrix25225-3Correlation
# F2-GrayLevelCooccurenceMatrix25225-4Correlation
# F2-GrayLevelCooccurenceMatrix25225-5Correlation
# F2-GrayLevelCooccurenceMatrix25225-6Correlation
# F2-GrayLevelCooccurenceMatrix25225-7Correlation
# F2-GrayLevelCooccurenceMatrix25270-1Correlation
# F2-GrayLevelCooccurenceMatrix25270-2Correlation
# F2-GrayLevelCooccurenceMatrix25270-3Correlation
# F2-GrayLevelCooccurenceMatrix25270-4Correlation
# F2-GrayLevelCooccurenceMatrix25270-5Correlation
# F2-GrayLevelCooccurenceMatrix25270-6Correlation
# F2-GrayLevelCooccurenceMatrix25270-7Correlation
# F2-GrayLevelCooccurenceMatrix25315-1Correlation
# F2-GrayLevelCooccurenceMatrix25315-2Correlation
# F2-GrayLevelCooccurenceMatrix25315-3Correlation
# F2-GrayLevelCooccurenceMatrix25315-4Correlation
# F2-GrayLevelCooccurenceMatrix25315-5Correlation
# F2-GrayLevelCooccurenceMatrix25315-6Correlation
# F2-GrayLevelCooccurenceMatrix25315-7Correlation
# F2-GrayLevelCooccurenceMatrix25-333-1DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix25-333-2DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix25-333-3DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix25-333-4DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix25-333-5DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix25-333-6DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix25-333-7DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix250-1DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix250-2DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix250-3DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix250-4DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix250-5DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix250-6DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix250-7DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix2545-1DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix2545-2DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix2545-3DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix2545-4DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix2545-5DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix2545-6DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix2545-7DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix2590-1DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix2590-2DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix2590-3DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix2590-4DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix2590-5DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix2590-6DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix2590-7DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix25135-1DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix25135-2DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix25135-3DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix25135-4DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix25135-5DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix25135-6DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix25135-7DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix25180-1DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix25180-2DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix25180-3DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix25180-4DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix25180-5DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix25180-6DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix25180-7DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix25225-1DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix25225-2DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix25225-3DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix25225-4DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix25225-5DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix25225-6DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix25225-7DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix25270-1DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix25270-2DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix25270-3DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix25270-4DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix25270-5DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix25270-6DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix25270-7DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix25315-1DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix25315-2DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix25315-3DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix25315-4DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix25315-5DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix25315-6DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix25315-7DifferenceEntropy
# F2-GrayLevelCooccurenceMatrix25-333-1Dissimilarity
# F2-GrayLevelCooccurenceMatrix25-333-2Dissimilarity
# F2-GrayLevelCooccurenceMatrix25-333-3Dissimilarity
# F2-GrayLevelCooccurenceMatrix25-333-4Dissimilarity
# F2-GrayLevelCooccurenceMatrix25-333-5Dissimilarity
# F2-GrayLevelCooccurenceMatrix25-333-6Dissimilarity
# F2-GrayLevelCooccurenceMatrix25-333-7Dissimilarity
# F2-GrayLevelCooccurenceMatrix250-1Dissimilarity
# F2-GrayLevelCooccurenceMatrix250-2Dissimilarity
# F2-GrayLevelCooccurenceMatrix250-3Dissimilarity
# F2-GrayLevelCooccurenceMatrix250-4Dissimilarity
# F2-GrayLevelCooccurenceMatrix250-5Dissimilarity
# F2-GrayLevelCooccurenceMatrix250-6Dissimilarity
# F2-GrayLevelCooccurenceMatrix250-7Dissimilarity
# F2-GrayLevelCooccurenceMatrix2545-1Dissimilarity
# F2-GrayLevelCooccurenceMatrix2545-2Dissimilarity
# F2-GrayLevelCooccurenceMatrix2545-3Dissimilarity
# F2-GrayLevelCooccurenceMatrix2545-4Dissimilarity
# F2-GrayLevelCooccurenceMatrix2545-5Dissimilarity
# F2-GrayLevelCooccurenceMatrix2545-6Dissimilarity
# F2-GrayLevelCooccurenceMatrix2545-7Dissimilarity
# F2-GrayLevelCooccurenceMatrix2590-1Dissimilarity
# F2-GrayLevelCooccurenceMatrix2590-2Dissimilarity
# F2-GrayLevelCooccurenceMatrix2590-3Dissimilarity
# F2-GrayLevelCooccurenceMatrix2590-4Dissimilarity
# F2-GrayLevelCooccurenceMatrix2590-5Dissimilarity
# F2-GrayLevelCooccurenceMatrix2590-6Dissimilarity
# F2-GrayLevelCooccurenceMatrix2590-7Dissimilarity
# F2-GrayLevelCooccurenceMatrix25135-1Dissimilarity
# F2-GrayLevelCooccurenceMatrix25135-2Dissimilarity
# F2-GrayLevelCooccurenceMatrix25135-3Dissimilarity
# F2-GrayLevelCooccurenceMatrix25135-4Dissimilarity
# F2-GrayLevelCooccurenceMatrix25135-5Dissimilarity
# F2-GrayLevelCooccurenceMatrix25135-6Dissimilarity
# F2-GrayLevelCooccurenceMatrix25135-7Dissimilarity
# F2-GrayLevelCooccurenceMatrix25180-1Dissimilarity
# F2-GrayLevelCooccurenceMatrix25180-2Dissimilarity
# F2-GrayLevelCooccurenceMatrix25180-3Dissimilarity
# F2-GrayLevelCooccurenceMatrix25180-4Dissimilarity
# F2-GrayLevelCooccurenceMatrix25180-5Dissimilarity
# F2-GrayLevelCooccurenceMatrix25180-6Dissimilarity
# F2-GrayLevelCooccurenceMatrix25180-7Dissimilarity
# F2-GrayLevelCooccurenceMatrix25225-1Dissimilarity
# F2-GrayLevelCooccurenceMatrix25225-2Dissimilarity
# F2-GrayLevelCooccurenceMatrix25225-3Dissimilarity
# F2-GrayLevelCooccurenceMatrix25225-4Dissimilarity
# F2-GrayLevelCooccurenceMatrix25225-5Dissimilarity
# F2-GrayLevelCooccurenceMatrix25225-6Dissimilarity
# F2-GrayLevelCooccurenceMatrix25225-7Dissimilarity
# F2-GrayLevelCooccurenceMatrix25270-1Dissimilarity
# F2-GrayLevelCooccurenceMatrix25270-2Dissimilarity
# F2-GrayLevelCooccurenceMatrix25270-3Dissimilarity
# F2-GrayLevelCooccurenceMatrix25270-4Dissimilarity
# F2-GrayLevelCooccurenceMatrix25270-5Dissimilarity
# F2-GrayLevelCooccurenceMatrix25270-6Dissimilarity
# F2-GrayLevelCooccurenceMatrix25270-7Dissimilarity
# F2-GrayLevelCooccurenceMatrix25315-1Dissimilarity
# F2-GrayLevelCooccurenceMatrix25315-2Dissimilarity
# F2-GrayLevelCooccurenceMatrix25315-3Dissimilarity
# F2-GrayLevelCooccurenceMatrix25315-4Dissimilarity
# F2-GrayLevelCooccurenceMatrix25315-5Dissimilarity
# F2-GrayLevelCooccurenceMatrix25315-6Dissimilarity
# F2-GrayLevelCooccurenceMatrix25315-7Dissimilarity
# F2-GrayLevelCooccurenceMatrix25-333-1Energy
# F2-GrayLevelCooccurenceMatrix25-333-2Energy
# F2-GrayLevelCooccurenceMatrix25-333-3Energy
# F2-GrayLevelCooccurenceMatrix25-333-4Energy
# F2-GrayLevelCooccurenceMatrix25-333-5Energy
# F2-GrayLevelCooccurenceMatrix25-333-6Energy
# F2-GrayLevelCooccurenceMatrix25-333-7Energy
# F2-GrayLevelCooccurenceMatrix250-1Energy
# F2-GrayLevelCooccurenceMatrix250-2Energy
# F2-GrayLevelCooccurenceMatrix250-3Energy
# F2-GrayLevelCooccurenceMatrix250-4Energy
# F2-GrayLevelCooccurenceMatrix250-5Energy
# F2-GrayLevelCooccurenceMatrix250-6Energy
# F2-GrayLevelCooccurenceMatrix250-7Energy
# F2-GrayLevelCooccurenceMatrix2545-1Energy
# F2-GrayLevelCooccurenceMatrix2545-2Energy
# F2-GrayLevelCooccurenceMatrix2545-3Energy
# F2-GrayLevelCooccurenceMatrix2545-4Energy
# F2-GrayLevelCooccurenceMatrix2545-5Energy
# F2-GrayLevelCooccurenceMatrix2545-6Energy
# F2-GrayLevelCooccurenceMatrix2545-7Energy
# F2-GrayLevelCooccurenceMatrix2590-1Energy
# F2-GrayLevelCooccurenceMatrix2590-2Energy
# F2-GrayLevelCooccurenceMatrix2590-3Energy
# F2-GrayLevelCooccurenceMatrix2590-4Energy
# F2-GrayLevelCooccurenceMatrix2590-5Energy
# F2-GrayLevelCooccurenceMatrix2590-6Energy
# F2-GrayLevelCooccurenceMatrix2590-7Energy
# F2-GrayLevelCooccurenceMatrix25135-1Energy
# F2-GrayLevelCooccurenceMatrix25135-2Energy
# F2-GrayLevelCooccurenceMatrix25135-3Energy
# F2-GrayLevelCooccurenceMatrix25135-4Energy
# F2-GrayLevelCooccurenceMatrix25135-5Energy
# F2-GrayLevelCooccurenceMatrix25135-6Energy
# F2-GrayLevelCooccurenceMatrix25135-7Energy
# F2-GrayLevelCooccurenceMatrix25180-1Energy
# F2-GrayLevelCooccurenceMatrix25180-2Energy
# F2-GrayLevelCooccurenceMatrix25180-3Energy
# F2-GrayLevelCooccurenceMatrix25180-4Energy
# F2-GrayLevelCooccurenceMatrix25180-5Energy
# F2-GrayLevelCooccurenceMatrix25180-6Energy
# F2-GrayLevelCooccurenceMatrix25180-7Energy
# F2-GrayLevelCooccurenceMatrix25225-1Energy
# F2-GrayLevelCooccurenceMatrix25225-2Energy
# F2-GrayLevelCooccurenceMatrix25225-3Energy
# F2-GrayLevelCooccurenceMatrix25225-4Energy
# F2-GrayLevelCooccurenceMatrix25225-5Energy
# F2-GrayLevelCooccurenceMatrix25225-6Energy
# F2-GrayLevelCooccurenceMatrix25225-7Energy
# F2-GrayLevelCooccurenceMatrix25270-1Energy
# F2-GrayLevelCooccurenceMatrix25270-2Energy
# F2-GrayLevelCooccurenceMatrix25270-3Energy
# F2-GrayLevelCooccurenceMatrix25270-4Energy
# F2-GrayLevelCooccurenceMatrix25270-5Energy
# F2-GrayLevelCooccurenceMatrix25270-6Energy
# F2-GrayLevelCooccurenceMatrix25270-7Energy
# F2-GrayLevelCooccurenceMatrix25315-1Energy
# F2-GrayLevelCooccurenceMatrix25315-2Energy
# F2-GrayLevelCooccurenceMatrix25315-3Energy
# F2-GrayLevelCooccurenceMatrix25315-4Energy
# F2-GrayLevelCooccurenceMatrix25315-5Energy
# F2-GrayLevelCooccurenceMatrix25315-6Energy
# F2-GrayLevelCooccurenceMatrix25315-7Energy
# F2-GrayLevelCooccurenceMatrix25-333-1Entropy
# F2-GrayLevelCooccurenceMatrix25-333-2Entropy
# F2-GrayLevelCooccurenceMatrix25-333-3Entropy
# F2-GrayLevelCooccurenceMatrix25-333-4Entropy
# F2-GrayLevelCooccurenceMatrix25-333-5Entropy
# F2-GrayLevelCooccurenceMatrix25-333-6Entropy
# F2-GrayLevelCooccurenceMatrix25-333-7Entropy
# F2-GrayLevelCooccurenceMatrix250-1Entropy
# F2-GrayLevelCooccurenceMatrix250-2Entropy
# F2-GrayLevelCooccurenceMatrix250-3Entropy
# F2-GrayLevelCooccurenceMatrix250-4Entropy
# F2-GrayLevelCooccurenceMatrix250-5Entropy
# F2-GrayLevelCooccurenceMatrix250-6Entropy
# F2-GrayLevelCooccurenceMatrix250-7Entropy
# F2-GrayLevelCooccurenceMatrix2545-1Entropy
# F2-GrayLevelCooccurenceMatrix2545-2Entropy
# F2-GrayLevelCooccurenceMatrix2545-3Entropy
# F2-GrayLevelCooccurenceMatrix2545-4Entropy
# F2-GrayLevelCooccurenceMatrix2545-5Entropy
# F2-GrayLevelCooccurenceMatrix2545-6Entropy
# F2-GrayLevelCooccurenceMatrix2545-7Entropy
# F2-GrayLevelCooccurenceMatrix2590-1Entropy
# F2-GrayLevelCooccurenceMatrix2590-2Entropy
# F2-GrayLevelCooccurenceMatrix2590-3Entropy
# F2-GrayLevelCooccurenceMatrix2590-4Entropy
# F2-GrayLevelCooccurenceMatrix2590-5Entropy
# F2-GrayLevelCooccurenceMatrix2590-6Entropy
# F2-GrayLevelCooccurenceMatrix2590-7Entropy
# F2-GrayLevelCooccurenceMatrix25135-1Entropy
# F2-GrayLevelCooccurenceMatrix25135-2Entropy
# F2-GrayLevelCooccurenceMatrix25135-3Entropy
# F2-GrayLevelCooccurenceMatrix25135-4Entropy
# F2-GrayLevelCooccurenceMatrix25135-5Entropy
# F2-GrayLevelCooccurenceMatrix25135-6Entropy
# F2-GrayLevelCooccurenceMatrix25135-7Entropy
# F2-GrayLevelCooccurenceMatrix25180-1Entropy
# F2-GrayLevelCooccurenceMatrix25180-2Entropy
# F2-GrayLevelCooccurenceMatrix25180-3Entropy
# F2-GrayLevelCooccurenceMatrix25180-4Entropy
# F2-GrayLevelCooccurenceMatrix25180-5Entropy
# F2-GrayLevelCooccurenceMatrix25180-6Entropy
# F2-GrayLevelCooccurenceMatrix25180-7Entropy
# F2-GrayLevelCooccurenceMatrix25225-1Entropy
# F2-GrayLevelCooccurenceMatrix25225-2Entropy
# F2-GrayLevelCooccurenceMatrix25225-3Entropy
# F2-GrayLevelCooccurenceMatrix25225-4Entropy
# F2-GrayLevelCooccurenceMatrix25225-5Entropy
# F2-GrayLevelCooccurenceMatrix25225-6Entropy
# F2-GrayLevelCooccurenceMatrix25225-7Entropy
# F2-GrayLevelCooccurenceMatrix25270-1Entropy
# F2-GrayLevelCooccurenceMatrix25270-2Entropy
# F2-GrayLevelCooccurenceMatrix25270-3Entropy
# F2-GrayLevelCooccurenceMatrix25270-4Entropy
# F2-GrayLevelCooccurenceMatrix25270-5Entropy
# F2-GrayLevelCooccurenceMatrix25270-6Entropy
# F2-GrayLevelCooccurenceMatrix25270-7Entropy
# F2-GrayLevelCooccurenceMatrix25315-1Entropy
# F2-GrayLevelCooccurenceMatrix25315-2Entropy
# F2-GrayLevelCooccurenceMatrix25315-3Entropy
# F2-GrayLevelCooccurenceMatrix25315-4Entropy
# F2-GrayLevelCooccurenceMatrix25315-5Entropy
# F2-GrayLevelCooccurenceMatrix25315-6Entropy
# F2-GrayLevelCooccurenceMatrix25315-7Entropy
# F2-GrayLevelCooccurenceMatrix25-333-1Homogeneity
# F2-GrayLevelCooccurenceMatrix25-333-2Homogeneity
# F2-GrayLevelCooccurenceMatrix25-333-3Homogeneity
# F2-GrayLevelCooccurenceMatrix25-333-4Homogeneity
# F2-GrayLevelCooccurenceMatrix25-333-5Homogeneity
# F2-GrayLevelCooccurenceMatrix25-333-6Homogeneity
# F2-GrayLevelCooccurenceMatrix25-333-7Homogeneity
# F2-GrayLevelCooccurenceMatrix250-1Homogeneity
# F2-GrayLevelCooccurenceMatrix250-2Homogeneity
# F2-GrayLevelCooccurenceMatrix250-3Homogeneity
# F2-GrayLevelCooccurenceMatrix250-4Homogeneity
# F2-GrayLevelCooccurenceMatrix250-5Homogeneity
# F2-GrayLevelCooccurenceMatrix250-6Homogeneity
# F2-GrayLevelCooccurenceMatrix250-7Homogeneity
# F2-GrayLevelCooccurenceMatrix2545-1Homogeneity
# F2-GrayLevelCooccurenceMatrix2545-2Homogeneity
# F2-GrayLevelCooccurenceMatrix2545-3Homogeneity
# F2-GrayLevelCooccurenceMatrix2545-4Homogeneity
# F2-GrayLevelCooccurenceMatrix2545-5Homogeneity
# F2-GrayLevelCooccurenceMatrix2545-6Homogeneity
# F2-GrayLevelCooccurenceMatrix2545-7Homogeneity
# F2-GrayLevelCooccurenceMatrix2590-1Homogeneity
# F2-GrayLevelCooccurenceMatrix2590-2Homogeneity
# F2-GrayLevelCooccurenceMatrix2590-3Homogeneity
# F2-GrayLevelCooccurenceMatrix2590-4Homogeneity
# F2-GrayLevelCooccurenceMatrix2590-5Homogeneity
# F2-GrayLevelCooccurenceMatrix2590-6Homogeneity
# F2-GrayLevelCooccurenceMatrix2590-7Homogeneity
# F2-GrayLevelCooccurenceMatrix25135-1Homogeneity
# F2-GrayLevelCooccurenceMatrix25135-2Homogeneity
# F2-GrayLevelCooccurenceMatrix25135-3Homogeneity
# F2-GrayLevelCooccurenceMatrix25135-4Homogeneity
# F2-GrayLevelCooccurenceMatrix25135-5Homogeneity
# F2-GrayLevelCooccurenceMatrix25135-6Homogeneity
# F2-GrayLevelCooccurenceMatrix25135-7Homogeneity
# F2-GrayLevelCooccurenceMatrix25180-1Homogeneity
# F2-GrayLevelCooccurenceMatrix25180-2Homogeneity
# F2-GrayLevelCooccurenceMatrix25180-3Homogeneity
# F2-GrayLevelCooccurenceMatrix25180-4Homogeneity
# F2-GrayLevelCooccurenceMatrix25180-5Homogeneity
# F2-GrayLevelCooccurenceMatrix25180-6Homogeneity
# F2-GrayLevelCooccurenceMatrix25180-7Homogeneity
# F2-GrayLevelCooccurenceMatrix25225-1Homogeneity
# F2-GrayLevelCooccurenceMatrix25225-2Homogeneity
# F2-GrayLevelCooccurenceMatrix25225-3Homogeneity
# F2-GrayLevelCooccurenceMatrix25225-4Homogeneity
# F2-GrayLevelCooccurenceMatrix25225-5Homogeneity
# F2-GrayLevelCooccurenceMatrix25225-6Homogeneity
# F2-GrayLevelCooccurenceMatrix25225-7Homogeneity
# F2-GrayLevelCooccurenceMatrix25270-1Homogeneity
# F2-GrayLevelCooccurenceMatrix25270-2Homogeneity
# F2-GrayLevelCooccurenceMatrix25270-3Homogeneity
# F2-GrayLevelCooccurenceMatrix25270-4Homogeneity
# F2-GrayLevelCooccurenceMatrix25270-5Homogeneity
# F2-GrayLevelCooccurenceMatrix25270-6Homogeneity
# F2-GrayLevelCooccurenceMatrix25270-7Homogeneity
# F2-GrayLevelCooccurenceMatrix25315-1Homogeneity
# F2-GrayLevelCooccurenceMatrix25315-2Homogeneity
# F2-GrayLevelCooccurenceMatrix25315-3Homogeneity
# F2-GrayLevelCooccurenceMatrix25315-4Homogeneity
# F2-GrayLevelCooccurenceMatrix25315-5Homogeneity
# F2-GrayLevelCooccurenceMatrix25315-6Homogeneity
# F2-GrayLevelCooccurenceMatrix25315-7Homogeneity
# F2-GrayLevelCooccurenceMatrix25-333-1Homogeneity2
# F2-GrayLevelCooccurenceMatrix25-333-2Homogeneity2
# F2-GrayLevelCooccurenceMatrix25-333-3Homogeneity2
# F2-GrayLevelCooccurenceMatrix25-333-4Homogeneity2
# F2-GrayLevelCooccurenceMatrix25-333-5Homogeneity2
# F2-GrayLevelCooccurenceMatrix25-333-6Homogeneity2
# F2-GrayLevelCooccurenceMatrix25-333-7Homogeneity2
# F2-GrayLevelCooccurenceMatrix250-1Homogeneity2
# F2-GrayLevelCooccurenceMatrix250-2Homogeneity2
# F2-GrayLevelCooccurenceMatrix250-3Homogeneity2
# F2-GrayLevelCooccurenceMatrix250-4Homogeneity2
# F2-GrayLevelCooccurenceMatrix250-5Homogeneity2
# F2-GrayLevelCooccurenceMatrix250-6Homogeneity2
# F2-GrayLevelCooccurenceMatrix250-7Homogeneity2
# F2-GrayLevelCooccurenceMatrix2545-1Homogeneity2
# F2-GrayLevelCooccurenceMatrix2545-2Homogeneity2
# F2-GrayLevelCooccurenceMatrix2545-3Homogeneity2
# F2-GrayLevelCooccurenceMatrix2545-4Homogeneity2
# F2-GrayLevelCooccurenceMatrix2545-5Homogeneity2
# F2-GrayLevelCooccurenceMatrix2545-6Homogeneity2
# F2-GrayLevelCooccurenceMatrix2545-7Homogeneity2
# F2-GrayLevelCooccurenceMatrix2590-1Homogeneity2
# F2-GrayLevelCooccurenceMatrix2590-2Homogeneity2
# F2-GrayLevelCooccurenceMatrix2590-3Homogeneity2
# F2-GrayLevelCooccurenceMatrix2590-4Homogeneity2
# F2-GrayLevelCooccurenceMatrix2590-5Homogeneity2
# F2-GrayLevelCooccurenceMatrix2590-6Homogeneity2
# F2-GrayLevelCooccurenceMatrix2590-7Homogeneity2
# F2-GrayLevelCooccurenceMatrix25135-1Homogeneity2
# F2-GrayLevelCooccurenceMatrix25135-2Homogeneity2
# F2-GrayLevelCooccurenceMatrix25135-3Homogeneity2
# F2-GrayLevelCooccurenceMatrix25135-4Homogeneity2
# F2-GrayLevelCooccurenceMatrix25135-5Homogeneity2
# F2-GrayLevelCooccurenceMatrix25135-6Homogeneity2
# F2-GrayLevelCooccurenceMatrix25135-7Homogeneity2
# F2-GrayLevelCooccurenceMatrix25180-1Homogeneity2
# F2-GrayLevelCooccurenceMatrix25180-2Homogeneity2
# F2-GrayLevelCooccurenceMatrix25180-3Homogeneity2
# F2-GrayLevelCooccurenceMatrix25180-4Homogeneity2
# F2-GrayLevelCooccurenceMatrix25180-5Homogeneity2
# F2-GrayLevelCooccurenceMatrix25180-6Homogeneity2
# F2-GrayLevelCooccurenceMatrix25180-7Homogeneity2
# F2-GrayLevelCooccurenceMatrix25225-1Homogeneity2
# F2-GrayLevelCooccurenceMatrix25225-2Homogeneity2
# F2-GrayLevelCooccurenceMatrix25225-3Homogeneity2
# F2-GrayLevelCooccurenceMatrix25225-4Homogeneity2
# F2-GrayLevelCooccurenceMatrix25225-5Homogeneity2
# F2-GrayLevelCooccurenceMatrix25225-6Homogeneity2
# F2-GrayLevelCooccurenceMatrix25225-7Homogeneity2
# F2-GrayLevelCooccurenceMatrix25270-1Homogeneity2
# F2-GrayLevelCooccurenceMatrix25270-2Homogeneity2
# F2-GrayLevelCooccurenceMatrix25270-3Homogeneity2
# F2-GrayLevelCooccurenceMatrix25270-4Homogeneity2
# F2-GrayLevelCooccurenceMatrix25270-5Homogeneity2
# F2-GrayLevelCooccurenceMatrix25270-6Homogeneity2
# F2-GrayLevelCooccurenceMatrix25270-7Homogeneity2
# F2-GrayLevelCooccurenceMatrix25315-1Homogeneity2
# F2-GrayLevelCooccurenceMatrix25315-2Homogeneity2
# F2-GrayLevelCooccurenceMatrix25315-3Homogeneity2
# F2-GrayLevelCooccurenceMatrix25315-4Homogeneity2
# F2-GrayLevelCooccurenceMatrix25315-5Homogeneity2
# F2-GrayLevelCooccurenceMatrix25315-6Homogeneity2
# F2-GrayLevelCooccurenceMatrix25315-7Homogeneity2
# F2-GrayLevelCooccurenceMatrix25-333-1InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix25-333-2InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix25-333-3InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix25-333-4InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix25-333-5InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix25-333-6InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix25-333-7InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix250-1InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix250-2InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix250-3InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix250-4InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix250-5InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix250-6InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix250-7InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix2545-1InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix2545-2InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix2545-3InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix2545-4InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix2545-5InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix2545-6InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix2545-7InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix2590-1InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix2590-2InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix2590-3InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix2590-4InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix2590-5InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix2590-6InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix2590-7InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix25135-1InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix25135-2InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix25135-3InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix25135-4InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix25135-5InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix25135-6InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix25135-7InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix25180-1InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix25180-2InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix25180-3InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix25180-4InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix25180-5InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix25180-6InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix25180-7InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix25225-1InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix25225-2InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix25225-3InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix25225-4InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix25225-5InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix25225-6InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix25225-7InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix25270-1InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix25270-2InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix25270-3InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix25270-4InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix25270-5InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix25270-6InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix25270-7InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix25315-1InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix25315-2InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix25315-3InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix25315-4InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix25315-5InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix25315-6InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix25315-7InformationMeasureCorr1
# F2-GrayLevelCooccurenceMatrix25-333-1InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix25-333-2InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix25-333-3InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix25-333-4InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix25-333-5InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix25-333-6InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix25-333-7InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix250-1InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix250-2InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix250-3InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix250-4InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix250-5InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix250-6InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix250-7InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix2545-1InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix2545-2InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix2545-3InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix2545-4InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix2545-5InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix2545-6InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix2545-7InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix2590-1InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix2590-2InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix2590-3InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix2590-4InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix2590-5InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix2590-6InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix2590-7InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix25135-1InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix25135-2InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix25135-3InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix25135-4InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix25135-5InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix25135-6InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix25135-7InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix25180-1InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix25180-2InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix25180-3InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix25180-4InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix25180-5InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix25180-6InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix25180-7InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix25225-1InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix25225-2InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix25225-3InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix25225-4InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix25225-5InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix25225-6InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix25225-7InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix25270-1InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix25270-2InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix25270-3InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix25270-4InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix25270-5InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix25270-6InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix25270-7InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix25315-1InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix25315-2InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix25315-3InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix25315-4InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix25315-5InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix25315-6InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix25315-7InformationMeasureCorr2
# F2-GrayLevelCooccurenceMatrix25-333-1InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix25-333-2InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix25-333-3InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix25-333-4InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix25-333-5InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix25-333-6InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix25-333-7InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix250-1InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix250-2InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix250-3InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix250-4InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix250-5InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix250-6InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix250-7InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix2545-1InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix2545-2InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix2545-3InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix2545-4InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix2545-5InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix2545-6InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix2545-7InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix2590-1InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix2590-2InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix2590-3InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix2590-4InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix2590-5InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix2590-6InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix2590-7InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix25135-1InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix25135-2InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix25135-3InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix25135-4InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix25135-5InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix25135-6InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix25135-7InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix25180-1InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix25180-2InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix25180-3InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix25180-4InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix25180-5InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix25180-6InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix25180-7InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix25225-1InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix25225-2InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix25225-3InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix25225-4InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix25225-5InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix25225-6InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix25225-7InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix25270-1InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix25270-2InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix25270-3InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix25270-4InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix25270-5InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix25270-6InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix25270-7InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix25315-1InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix25315-2InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix25315-3InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix25315-4InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix25315-5InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix25315-6InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix25315-7InverseDiffMomentNorm
# F2-GrayLevelCooccurenceMatrix25-333-1InverseDiffNorm
# F2-GrayLevelCooccurenceMatrix25-333-2InverseDiffNorm
# Overall Survival (4 Years)
# /tmp/ipykernel_2197865/2568970569.py:1: DtypeWarning: Columns (55) have mixed types. Specify dtype option on import or set low_memory=False.
#   for c in pd.read_csv('../data/digital_twin_data.csv').columns:
# /tmp/ipykernel_2197865/2568970569.py:3: DtypeWarning: Columns (55) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv('../data/digital_twin_data.csv')['ROI'].unique()
# array(['GTVp1', nan], dtype=object)

# %%
pd.get_dummies(pd.read_csv('../data/digital_twin_data.csv')['Race']).sum()
# Out:
# /tmp/ipykernel_2197865/3189273113.py:1: DtypeWarning: Columns (55) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.get_dummies(pd.read_csv('../data/digital_twin_data.csv')['Race']).sum()
# African American/Black     16
# Asian                       4
# Hispanic/Latino            21
# NOS                         5
# Native American             1
# White/Caucasion           489
# dtype: int64

# %%
class DTDataset():
    
    def __init__(self,data_file = '../data/digital_twin_data.csv',ln_data_file = '../data/digital_twin_ln_data.csv',ids=None):
        df = pd.read_csv(data_file)
        df = preprocess(df)
        df = df.rename(columns = Const.rename_dict).copy()
        df = df.drop('MRN OPC',axis=1)

        ln_data = pd.read_csv(ln_data_file)
        ln_data = ln_data.rename(columns={'cluster':'ln_cluster'})
        self.ln_cols = [c for c in ln_data.columns if c not in df.columns]
        df = df.merge(ln_data,on='id')
        df.index = df.index.astype(int)
        if ids is not None:
            df = df[df.id.apply(lambda x: x in ids)]
        self.processed_df = preprocess_dt_data(df,self.ln_cols).fillna(0)
        
        self.means = self.processed_df.mean(axis=0)
        self.stds = self.processed_df.std(axis=0)
        self.maxes = self.processed_df.max(axis=0)
        self.mins = self.processed_df.min(axis=0)
        
        arrays = self.get_states()
        self.state_sizes = {k: (v.shape[1] if v.ndim > 1 else 1) for k,v in arrays.items()}
        
    def get_data(self):
        return self.processed_df
    
    def sample(self,frac=.5):
        return self.processed_df.sample(frac=frac)
    
    def split_sample(self,ratio = .3):
        assert(ratio > 0 and ratio <= 1)
        df1 = self.processed_df.sample(frac=1-ratio)
        df2 = self.processed_df.drop(index=df1.index)
        return df1,df2
    
    def get_states(self,fixed=None,ids = None):
        processed_df = self.processed_df.copy()
        if ids is not None:
            processed_df = processed_df.loc[ids]
        if fixed is not None:
            for col,val in fixed.items():
                if col in processed_df.columns:
                    processed_df[col] = val
                else:
                    print('bad fixed entry',col)
                    
        to_skip = ['CC Regimen(0= none, 1= platinum based, 2= cetuximab based, 3= others, 9=unknown)','DLT_Type','DLT 2'] + [c for c in processed_df.columns if 'treatment' in c]
        other_states = set(Const.decisions + Const.state3 + Const.state2 + Const.outcomes  + to_skip)

        base_state = sorted([c for c in processed_df.columns if c not in other_states])

        dlt1 = Const.dlt1
        dlt2 = Const.dlt2
        
        modifications = Const.modifications
        ccs = Const.ccs
        pds = Const.primary_disease_states
        nds = Const.nodal_disease_states
        pds2 = Const.primary_disease_states2
        nds2 = Const.nodal_disease_states2
        outcomes = Const.outcomes
        decisions= Const.decisions
        
        #intermediate states are only udated values. Models should use baseline + state2 etc
        results = {
            'baseline': processed_df[base_state],
            'pd_states1': processed_df[pds],
            'nd_states1': processed_df[nds],
            'modifications': processed_df[modifications],
            'ccs': processed_df[ccs],
            'pd_states2': processed_df[pds2],
            'nd_states2': processed_df[nds2],
            'outcomes': processed_df[outcomes],
            'dlt1': processed_df[dlt1],
            'dlt2': processed_df[dlt2],
            'decision1': processed_df[decisions[0]],
            'decision2': processed_df[decisions[1]],
            'decision3': processed_df[decisions[2]],
            'survival': processed_df[outcomes[0]],
            'ft': processed_df[outcomes[1]],
            'aspiration': processed_df[outcomes[2]],
        }
    
        return results
    
    def get_state(self,name,**kwargs):
        return self.get_states(**kwargs)[name]
    
    def normalize(self,df):
        means = self.means[df.columns]
        std = self.stds[df.columns]
        return ((df - means)/std).fillna(0)
    
    def get_intermediate_outcomes(self,step=1,**kwargs):
        assert(step in [0,1,2,3])
        states = self.get_states(**kwargs)
        if step == 1:
            keys = ['pd_states1','nd_states1','modifications','dlt1']
        if step == 2:
            keys =  ['pd_states2','nd_states2','ccs','dlt2']
        if step == 3:
            keys = ['survival','ft','aspiration']# ['decision1','decision2','decision3']
        if step == 0:
            keys = ['decision1','decision2','decision3']
        if len(keys) < 2:
            return states[keys[0]]
        return [states[key] for key in keys]
    
    def get_input_state(self,step=1,**kwargs):
        assert(step in [0,1,2,3])
        states = self.get_states(**kwargs)
        if step == 0:
            keys = ['baseline']
        if step == 1:
            keys = ['baseline','decision1']
        if step == 2:
            keys =  ['baseline','pd_states1','nd_states1','modifications','dlt1','decision1','decision2']
        if step == 3:
            keys = ['baseline','pd_states2','nd_states2','ccs','dlt2','decision1','decision2','decision3']
        arrays = [states[key] for key in keys]
        if len(arrays) < 2:
            return arrays[0]
        return pd.concat(arrays,axis=1)
    
data = DTDataset()
data.get_intermediate_outcomes(step=0)
# Out:
# /tmp/ipykernel_2197865/3254291764.py:4: DtypeWarning: Columns (55) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(data_file)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Tm Laterality (R/L)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[201], line 127
#     124             return arrays[0]
#     125         return pd.concat(arrays,axis=1)
# --> 127 data = DTDataset()
#     128 data.get_intermediate_outcomes(step=0)
#
# Cell In[201], line 16, in DTDataset.__init__(self, data_file, ln_data_file, ids)
#      14 if ids is not None:
#      15     df = df[df.id.apply(lambda x: x in ids)]
# ---> 16 self.processed_df = preprocess_dt_data(df,self.ln_cols).fillna(0)
#      18 self.means = self.processed_df.mean(axis=0)
#      19 self.stds = self.processed_df.std(axis=0)
#
# Cell In[200], line 165, in preprocess_dt_data(df, extra_to_keep)
#     161     df[col] = df[col].apply(lambda x: int(x == 'Y'))
#     163 to_keep = to_keep + [c for c in df.columns if 'DLT' in c]
# --> 165 df['bilateral'] = df['Tm Laterality (R/L)'].apply(lambda x: x.lower().strip() == 'bilateral')
#     166 to_keep.append('bilateral')
#     168 for statelist in [Const.state2,Const.state3,Const.decisions,Const.outcomes]:
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 'Tm Laterality (R/L)'

# %%
def df_to_torch(df,ttype  = torch.FloatTensor):
    values = df.values.astype(float)
    values = torch.from_numpy(values)
    return values.type(ttype)

# %%
class SimulatorBase(torch.nn.Module):
    
    def __init__(self,
                 input_size,
                 hidden_layers = [1000],
                 dropout = 0.5,
                 input_dropout=0.1,
                 state = 1,
                 eps = 0.01,
                ):
        #predicts disease state (sd, pr, cr) for primar and nodal, then dose modications or cc type (depending on state), and [dlt ratings]
        torch.nn.Module.__init__(self)
        self.state = state
        self.input_dropout = torch.nn.Dropout(input_dropout)
        
        first_layer =torch.nn.Linear(input_size,hidden_layers[0],bias=True)
        layers = [first_layer,torch.nn.ReLU()]
        curr_size = hidden_layers[0]
        for ndim in hidden_layers[1:]:
            layer = torch.nn.Linear(curr_size,ndim)
            curr_size = ndim
            layers.append(layer)
            layers.append(torch.nn.ReLU())
        self.layers = torch.nn.ModuleList(layers)
        self.batchnorm = torch.nn.BatchNorm1d(hidden_layers[-1])
        self.dropout = torch.nn.Dropout(dropout)
        
    
        input_mean = torch.tensor([0])
        input_std = torch.tensor([1])
        self.eps = eps
        self.register_buffer('input_mean', input_mean)
        self.register_buffer('input_std',input_std)
        
        self.softmax = torch.nn.LogSoftmax(dim=1)
        self.identifier = 'state'  +str(state) + '_input'+str(input_size) + '_dims' + ','.join([str(h) for h in hidden_layers]) + '_dropout' + str(input_dropout) + ',' + str(dropout)
        
    def normalize(self,x):
        x = (x - self.input_mean + self.eps)/(self.input_std + self.eps)
        return x
    
    def fit_normalizer(self,x):
        input_mean = x.mean(axis=0)
        input_std = x.std(axis=0)
        self.register_buffer('input_mean', input_mean)
        self.register_buffer('input_std',input_std)
        return True
        
class OutcomeSimulator(SimulatorBase):
    
    def __init__(self,
                 input_size,
                 hidden_layers = [1000,1000],
                 dropout = 0.5,
                 input_dropout=0.1,
                 state = 1,
                ):
        #predicts disease state (sd, pr, cr) for primar and nodal, then dose modications or cc type (depending on state), and [dlt ratings]
        super(OutcomeSimulator,self).__init__(input_size,hidden_layers=hidden_layers,dropout=dropout,input_dropout=input_dropout,state=state)
    
        self.disease_layer = torch.nn.Linear(hidden_layers[-1],len(Const.primary_disease_states))
        self.nodal_disease_layer = torch.nn.Linear(hidden_layers[-1],len(Const.nodal_disease_states))
        #dlt ratings are 0-4 even though they don't always appear
        
        assert( state in [1,2])
        if state == 1:
            self.dlt_layers = torch.nn.ModuleList([torch.nn.Linear(hidden_layers[-1],5) for i in Const.dlt1])
            self.treatment_layer = torch.nn.Linear(hidden_layers[-1],len(Const.modifications))
        else:
            #we only have dlt yes or no for the second state?
            self.dlt_layers = torch.nn.ModuleList([torch.nn.Linear(hidden_layers[-1],2) for i in Const.dlt2])
            self.treatment_layer = torch.nn.Linear(hidden_layers[-1],len(Const.ccs))

    def forward(self,x):
        x = self.normalize(x)
        x = self.input_dropout(x)
        for layer in self.layers:
            x = layer(x)
#         x = self.batchnorm(x)
        x = self.dropout(x)
        x_pd = self.disease_layer(x)
        x_nd = self.nodal_disease_layer(x)
        x_mod = self.treatment_layer(x)
        x_dlts = [layer(x) for layer in self.dlt_layers]
        
        x_pd = self.softmax(x_pd)
        x_nd = self.softmax(x_nd)
        x_mod = self.softmax(x_mod)
        #dlts are array of nbatch x n_dlts x predictions
        x_dlts = torch.stack([self.softmax(xx) for xx in x_dlts],axis=1)
        return [x_pd, x_nd, x_mod, x_dlts]
    
class EndpointSimulator(SimulatorBase):
    
    def __init__(self,
                 input_size,
                 hidden_layers = [500],
                 dropout = 0.5,
                 input_dropout=0.1,
                 state = 1,
                ):
        #predicts disease state (sd, pr, cr) for primar and nodal, then dose modications or cc type (depending on state), and [dlt ratings]
        super(EndpointSimulator,self).__init__(input_size,hidden_layers=hidden_layers,dropout=dropout,input_dropout=input_dropout,state=state)
        
        self.outcome_layer = torch.nn.Linear(hidden_layers[-1],len(Const.outcomes))
        self.sigmoid = torch.nn.Sigmoid()
      
        
    def forward(self,x):
        x = self.normalize(x)
        x = self.input_dropout(x)
        for layer in self.layers:
            x = layer(x)
#         x = self.batchnorm(x)
        x = self.dropout(x)
        x= self.outcome_layer(x)
        x = self.sigmoid(x)
        return x

OutcomeSimulator(3).input_mean
# Out:
# tensor([0])

# %%
def nllloss(ytrue,ypred):
    #nll loss with argmax added in
    loss = torch.nn.NLLLoss()
    return loss(ypred,ytrue.argmax(axis=1))

def state_loss(ytrue,ypred,weights=[1,1,1,1]):
    pd_loss = nllloss(ytrue[0],ypred[0])*weights[0]
    nd_loss = nllloss(ytrue[1],ypred[1])*weights[1]
    mod_loss = nllloss(ytrue[2],ypred[2])*weights[2]
    loss = pd_loss + nd_loss + mod_loss
    dlt_true = ytrue[3]
    dlt_pred = ypred[3]
    ndlt = dlt_true.shape[1]
    nloss = torch.nn.NLLLoss()
    for i in range(ndlt):
        dlt_loss = nloss(dlt_pred[:,i,:],dlt_true[:,i].type(torch.LongTensor))
        loss += dlt_loss*weights[3]/ndlt
    return loss

def outcome_loss(ytrue,ypred,weights=[1,1,1]):
    loss = 0
    nloss = torch.nn.BCELoss()
    for i in range(len(weights)):
        iloss = nloss(ypred[:,i],ytrue[i])*weights[i]
        loss += iloss
    return loss

from sklearn.metrics import balanced_accuracy_score, roc_auc_score

def mc_metrics(yt,yp,numpy=False,is_dlt=False):
    if not numpy:
        yt = yt .cpu().detach().numpy()
        yp = yp.cpu().detach().numpy()
    #this is a catch for when I se the dlt prediction format (encoded integer ordinal, predict as a categorical and take the argmax)
    if yt.ndim > 1:
        try:
            bacc = balanced_accuracy_score(yt.argmax(axis=1),yp.argmax(axis=1))
        except:
            bacc = -1
        try:
            roc_micro = roc_auc_score(yt,yp,average='micro')
        except:
            roc_micro=-1
        try:
            roc_macro = roc_auc_score(yt,yp,average='macro')
        except:
            roc_macro = -1
        return {'accuracy': bacc, 'roc_micro': roc_micro,'roc_macro': roc_macro}
    else:
        if yp.ndim > 1:
            yp = yp.argmax(axis=1)
        try:
            bacc = balanced_accuracy_score(yt,yp)
        except:
            bacc = -1
        try:
            if is_dlt:
                roc = roc_auc_score(yt > 0, yp > 0)
            else:
                roc = roc_auc_score(yt ,yp )
        except:
            roc = -1
        error = np.mean((yt-yp)**2)
        return {'accuracy': bacc, 'mse': error, 'auc': roc}

def state_metrics(ytrue,ypred,numpy=False):
    pd_metrics = mc_metrics(ytrue[0],ypred[0],numpy=numpy)
    nd_metrics = mc_metrics(ytrue[1],ypred[1],numpy=numpy)
    mod_metrics = mc_metrics(ytrue[1],ypred[1],numpy=numpy)
    
    dlt_metrics = []
    dlt_true = ytrue[3]
    dlt_pred = ypred[3]
    ndlt = dlt_true.shape[1]
    nloss = torch.nn.NLLLoss()
    for i in range(ndlt):
        dm = mc_metrics(dlt_true[:,i],dlt_pred[:,i,:],is_dlt=True)
        dlt_metrics.append(dm)
    dlt_acc =[d['accuracy'] for d in dlt_metrics]
    dlt_error = [d['mse'] for d in dlt_metrics]
    dlt_auc = [d['auc'] for d in dlt_metrics]
    return {'pd': pd_metrics,'nd': nd_metrics,'mod': mod_metrics,'dlts': {'accuracy': dlt_acc,'accuracy_mean': np.mean(dlt_acc),'auc': dlt_auc,'auc_mean': np.mean(dlt_auc)}}
    
def outcome_metrics(ytrue,ypred,numpy=False):
    res = {}
    for i, outcome in enumerate(Const.outcomes):
        metrics = mc_metrics(ytrue[i],ypred[:,i])
        res[outcome] = metrics
    return res
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/multiclass.py:13: DeprecationWarning: Please use `spmatrix` from the `scipy.sparse` namespace, the `scipy.sparse.base` namespace is deprecated.
#   from scipy.sparse.base import spmatrix

# %%
from sklearn.ensemble import RandomForestClassifier

def train_state_rf(model_args={}):
    ids = get_dt_ids()
    
    dataset = DTDataset()

    train_ids = ids[0:int(len(ids)*.7)]
    test_ids = ids[int(len(ids)*.7):]
    
    #most things are multiclass, dlts are several ordinal and outcomes are multiple binary
    xtrain1 = dataset.get_state('baseline',ids=train_ids)
    xtest1 = dataset.get_state('baseline',ids=test_ids)
    
    xtrain2 = dataset.get_input_state(step=2,ids=train_ids)
    xtest2 = dataset.get_input_state(step=2,ids=test_ids)
    
    xtrain3 = dataset.get_input_state(step=3,ids=train_ids)
    xtest3 = dataset.get_input_state(step=3,ids=test_ids)
    
    [pd1_train,nd1_train, mod_train,dlts1_train] = dataset.get_intermediate_outcomes(ids=train_ids)
    [pd2_train,nd2_train, cc_train,dlts2_train] = dataset.get_intermediate_outcomes(step=2,ids=train_ids)
    [pd1_test,nd1_test, mod_test,dlts1_test] = dataset.get_intermediate_outcomes(ids=test_ids)
    [pd2_test,nd2_test, cc_test,dlts2_test] = dataset.get_intermediate_outcomes(step=2,ids=test_ids)
    outcomes_train = dataset.get_state('outcomes',ids=train_ids)
    outcomes_test = dataset.get_state('outcomes',ids=test_ids)
    

    def train_multiclass_rf(xtrain,xtest,ytrain,ytest):
        model = RandomForestClassifier(class_weight='balanced',**model_args).fit(xtrain,ytrain)
        ypred = model.predict(xtest)
        metrics = mc_metrics(ytest.values,ypred,numpy=True)
        return model, metrics
    
    all_metrics = {}
    pd1_model, all_metrics['pd1'] = train_multiclass_rf(xtrain1,xtest1,pd1_train,pd1_test)
    nd1_model, all_metrics['nd1']  = train_multiclass_rf(xtrain1,xtest1,nd1_train,nd1_test)
    mod_model, all_metrics['mod']  = train_multiclass_rf(xtrain1,xtest1,mod_train,mod_test)
    
    return all_metrics

# train_state_rf({'max_depth': 5,'n_estimators': 100})
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/least_angle.py:30: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   method='lar', copy_X=True, eps=np.finfo(np.float).eps,
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/least_angle.py:167: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   method='lar', copy_X=True, eps=np.finfo(np.float).eps,
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/least_angle.py:284: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_Gram=True, verbose=0,
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/least_angle.py:862: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, fit_path=True,
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/least_angle.py:1101: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, fit_path=True,
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/least_angle.py:1127: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, positive=False):
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/least_angle.py:1362: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_n_alphas=1000, n_jobs=None, eps=np.finfo(np.float).eps,
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/least_angle.py:1602: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_n_alphas=1000, n_jobs=None, eps=np.finfo(np.float).eps,
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/least_angle.py:1738: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, positive=False):
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/optimize.py:18: DeprecationWarning: Please use `line_search_wolfe2` from the `scipy.optimize` namespace, the `scipy.optimize.linesearch` namespace is deprecated.
#   from scipy.optimize.linesearch import line_search_wolfe2, line_search_wolfe1
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/optimize.py:18: DeprecationWarning: Please use `line_search_wolfe1` from the `scipy.optimize` namespace, the `scipy.optimize.linesearch` namespace is deprecated.
#   from scipy.optimize.linesearch import line_search_wolfe2, line_search_wolfe1
# /usr/local/lib/python3.8/dist-packages/sklearn/decomposition/online_lda.py:29: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   EPS = np.finfo(np.float).eps
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/gradient_boosting.py:32: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from ._gradient_boosting import predict_stages
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/gradient_boosting.py:32: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from ._gradient_boosting import predict_stages

# %%
def train_state(model_args={},
                state=1,
                split=.7,
                lr=.0001,
                epochs=1000,
                patience=10,
                weights=[1,1,1,10],
                save_path='../data/models/',
                resample_training=False,#use bootstraping on training data after splitting
                resample_all = False,# use bootstrapping, then validate with out-of-bag data
                file_suffix=''):
    
    ids = get_dt_ids()
    
    if resample_all:
        train_ids = np.random.choice(ids,len(ids),replace=True)
        test_ids = [i for i in ids if i not in train_ids]
    
    else:
        train_ids = ids[0:int(len(ids)*split)]
        if resample_training:
            train_ids = np.random.choice(train_ids,len(train_ids),replace=True)
        test_ids = ids[int(len(ids)*split):]
    
    dataset = DTDataset()
    
    xtrain = dataset.get_input_state(step=state,ids=train_ids)
    xtest = dataset.get_input_state(step=state,ids=test_ids)
    ytrain = dataset.get_intermediate_outcomes(step=state,ids=train_ids)
    ytest = dataset.get_intermediate_outcomes(step=state,ids=test_ids)
    

    if state < 3:
        model = OutcomeSimulator(xtrain.shape[1],state=state,**model_args)
        lfunc = state_loss
    else:
        model = EndpointSimulator(xtrain.shape[1],**model_args)
        weights = weights[:3]
        lfunc = outcome_loss
        
    hashcode = str(hash(','.join([str(i) for i in train_ids])))
    save_file = save_path + 'model_' + model.identifier + '_split' + str(split) + '_resample' + str(resample_training) +  '_hash' + hashcode + file_suffix + '.tar'
    xtrain = df_to_torch(xtrain)
    xtest = df_to_torch(xtest)
    ytrain = [df_to_torch(t) for t in ytrain]
    ytest= [df_to_torch(t) for t in ytest]
    
    model.fit_normalizer(xtrain)
#     normalize = lambda x: (x - xtrain.mean(axis=0)+.01)/(xtrain.std(axis=0)+.01)
#     unnormalize = lambda x: (x * (xtrain.std(axis=0) +.01)) + xtrain.mean(axis=0) - .01
    
    optimizer = torch.optim.Adam(model.parameters(),lr=lr)
    best_val_loss = 1000000000000000000000000000
    best_loss_metrics = {}
    for epoch in range(epochs):
        
        model.train(True)
        optimizer.zero_grad()
        
        xtrain_sample = xtrain#[torch.randint(len(xtrain),(len(xtrain),) )]
        ypred = model(xtrain_sample)
        loss = lfunc(ytrain,ypred,weights=weights)

        loss.backward()
        optimizer.step()
        print('epoch',epoch,'train loss',loss.item())
        
        model.eval()
        yval = model(xtest)
        val_loss = lfunc(ytest,yval,weights=weights)
        if state < 3:
            val_metrics = state_metrics(ytest,yval)
        else:
            val_metrics = outcome_metrics(ytest,yval)
        if val_loss.item() < best_val_loss:
            best_val_loss = val_loss.item()
            best_loss_metrics = val_metrics
            steps_since_improvement = 0
            torch.save(model.state_dict(),save_file)
        else:
            steps_since_improvement += 1
        print('val loss',val_loss.item())
        print('______________')
        if steps_since_improvement > patience:
            break
    print('best loss',best_val_loss,best_loss_metrics)
    model.load_state_dict(torch.load(save_file))
    model = model.eval()
    return model
model = train_state(state=1)
model
# Out:
# /tmp/ipykernel_2197865/1992661605.py:2: DtypeWarning: Columns (55) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# /tmp/ipykernel_2197865/1521532340.py:4: DtypeWarning: Columns (55) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(data_file)
# /tmp/ipykernel_2197865/1521532340.py:19: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   self.means = self.processed_df.mean(axis=0)
# /tmp/ipykernel_2197865/1521532340.py:20: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   self.stds = self.processed_df.std(axis=0)
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# epoch 0 train loss 20.31390380859375
# val loss 19.554641723632812
# ______________
# epoch 1 train loss 19.594619750976562
# val loss 18.907915115356445
# ______________
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# epoch 2 train loss 18.947132110595703
# val loss 18.26899528503418
# ______________
# epoch 3 train loss 18.26720428466797
# val loss 17.633028030395508
# ______________
# epoch 4 train loss 17.62619400024414
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# val loss 16.996232986450195
# ______________
# epoch 5 train loss 16.96844482421875
# val loss 16.355268478393555
# ______________
# epoch 6 train loss 16.319337844848633
# val loss 15.707328796386719
# ______________
# epoch 7 train loss 15.674251556396484
# val loss 15.051858901977539
# ______________
# epoch 8 train loss 15.008088111877441
# val loss 14.388801574707031
# ______________
# epoch 9 train loss 14.296045303344727
# val loss 13.719712257385254
# ______________
# epoch 10 train loss 13.625718116760254
# val loss 13.046521186828613
# ______________
# epoch 11 train loss 12.941590309143066
# val loss 12.372965812683105
# ______________
# epoch 12 train loss 12.259780883789062
# val loss 11.703165054321289
# ______________
# epoch 13 train loss 11.576982498168945
# val loss 11.042352676391602
# ______________
# epoch 14 train loss 10.88326644897461
# val loss 10.39614200592041
# ______________
# epoch 15 train loss 10.168752670288086
# val loss 9.769389152526855
# ______________
# epoch 16 train loss 9.645013809204102
# val loss 9.167439460754395
# ______________
# epoch 17 train loss 8.93923568725586
# val loss 8.595657348632812
# ______________
# epoch 18 train loss 8.394450187683105
# val loss 8.058231353759766
# ______________
# epoch 19 train loss 7.851687908172607
# val loss 7.5585832595825195
# ______________
# epoch 20 train loss 7.344419479370117
# val loss 7.098883152008057
# ______________
# epoch 21 train loss 6.868550777435303
# val loss 6.680421829223633
# ______________
# epoch 22 train loss 6.444400787353516
# val loss 6.303488731384277
# ______________
# epoch 23 train loss 6.046125411987305
# val loss 5.967206001281738
# ______________
# epoch 24 train loss 5.677136421203613
# val loss 5.670422554016113
# ______________
# epoch 25 train loss 5.424500465393066
# val loss 5.410612106323242
# ______________
# epoch 26 train loss 5.137260913848877
# val loss 5.185021877288818
# ______________
# epoch 27 train loss 4.868043899536133
# val loss 4.990640163421631
# ______________
# epoch 28 train loss 4.6311845779418945
# val loss 4.824095726013184
# ______________
# epoch 29 train loss 4.497529983520508
# val loss 4.682061195373535
# ______________
# epoch 30 train loss 4.3730316162109375
# val loss 4.561037540435791
# ______________
# epoch 31 train loss 4.1956706047058105
# val loss 4.4581804275512695
# ______________
# epoch 32 train loss 4.093595027923584
# val loss 4.37065315246582
# ______________
# epoch 33 train loss 4.015478610992432
# val loss 4.295652389526367
# ______________
# epoch 34 train loss 3.8994266986846924
# val loss 4.230891704559326
# ______________
# epoch 35 train loss 3.774536609649658
# val loss 4.174422740936279
# ______________
# epoch 36 train loss 3.8216464519500732
# val loss 4.1244988441467285
# ______________
# epoch 37 train loss 3.7103545665740967
# val loss 4.079559326171875
# ______________
# epoch 38 train loss 3.5990047454833984
# val loss 4.038149356842041
# ______________
# epoch 39 train loss 3.597944498062134
# val loss 3.9991273880004883
# ______________
# epoch 40 train loss 3.5690765380859375
# val loss 3.961794376373291
# ______________
# epoch 41 train loss 3.479762077331543
# val loss 3.9254372119903564
# ______________
# epoch 42 train loss 3.4631383419036865
# val loss 3.889388084411621
# ______________
# epoch 43 train loss 3.379509449005127
# val loss 3.8535540103912354
# ______________
# epoch 44 train loss 3.403355121612549
# val loss 3.8173987865448
# ______________
# epoch 45 train loss 3.3362975120544434
# val loss 3.780897617340088
# ______________
# epoch 46 train loss 3.319845199584961
# val loss 3.7436020374298096
# ______________
# epoch 47 train loss 3.2383487224578857
# val loss 3.7058658599853516
# ______________
# epoch 48 train loss 3.2205092906951904
# val loss 3.667558193206787
# ______________
# epoch 49 train loss 3.1771957874298096
# val loss 3.629075527191162
# ______________
# epoch 50 train loss 3.1366982460021973
# val loss 3.590777635574341
# ______________
# epoch 51 train loss 3.087031364440918
# val loss 3.552919626235962
# ______________
# epoch 52 train loss 3.0182113647460938
# val loss 3.516005754470825
# ______________
# epoch 53 train loss 3.0192761421203613
# val loss 3.480287790298462
# ______________
# epoch 54 train loss 3.0495545864105225
# val loss 3.445791721343994
# ______________
# epoch 55 train loss 2.981703042984009
# val loss 3.4129762649536133
# ______________
# epoch 56 train loss 2.8929665088653564
# val loss 3.381700277328491
# ______________
# epoch 57 train loss 2.9731674194335938
# val loss 3.352015256881714
# ______________
# epoch 58 train loss 2.880666494369507
# val loss 3.3237035274505615
# ______________
# epoch 59 train loss 2.843977451324463
# val loss 3.2971038818359375
# ______________
# epoch 60 train loss 2.773211717605591
# val loss 3.2715907096862793
# ______________
# epoch 61 train loss 2.772000551223755
# val loss 3.247199773788452
# ______________
# epoch 62 train loss 2.823410749435425
# val loss 3.2236666679382324
# ______________
# epoch 63 train loss 2.7561192512512207
# val loss 3.200854539871216
# ______________
# epoch 64 train loss 2.71583890914917
# val loss 3.178990364074707
# ______________
# epoch 65 train loss 2.7049448490142822
# val loss 3.157869577407837
# ______________
# epoch 66 train loss 2.671320676803589
# val loss 3.137441396713257
# ______________
# epoch 67 train loss 2.716644525527954
# val loss 3.117323637008667
# ______________
# epoch 68 train loss 2.681093215942383
# val loss 3.097831964492798
# ______________
# epoch 69 train loss 2.617628335952759
# val loss 3.0791447162628174
# ______________
# epoch 70 train loss 2.574805498123169
# val loss 3.061002254486084
# ______________
# epoch 71 train loss 2.534473419189453
# val loss 3.0429930686950684
# ______________
# epoch 72 train loss 2.5230770111083984
# val loss 3.025054693222046
# ______________
# epoch 73 train loss 2.491403579711914
# val loss 3.0073015689849854
# ______________
# epoch 74 train loss 2.5164074897766113
# val loss 2.9895172119140625
# ______________
# epoch 75 train loss 2.5181291103363037
# val loss 2.9722485542297363
# ______________
# epoch 76 train loss 2.4244279861450195
# val loss 2.9554474353790283
# ______________
# epoch 77 train loss 2.4153363704681396
# val loss 2.938857078552246
# ______________
# epoch 78 train loss 2.3919224739074707
# val loss 2.922851800918579
# ______________
# epoch 79 train loss 2.4182233810424805
# val loss 2.907404661178589
# ______________
# epoch 80 train loss 2.341935396194458
# val loss 2.8919241428375244
# ______________
# epoch 81 train loss 2.376096725463867
# val loss 2.8766062259674072
# ______________
# epoch 82 train loss 2.313249349594116
# val loss 2.861480712890625
# ______________
# epoch 83 train loss 2.332872152328491
# val loss 2.846220016479492
# ______________
# epoch 84 train loss 2.2889599800109863
# val loss 2.83095121383667
# ______________
# epoch 85 train loss 2.259612560272217
# val loss 2.815624952316284
# ______________
# epoch 86 train loss 2.254107713699341
# val loss 2.8001840114593506
# ______________
# epoch 87 train loss 2.2644670009613037
# val loss 2.784787654876709
# ______________
# epoch 88 train loss 2.192049264907837
# val loss 2.769256114959717
# ______________
# epoch 89 train loss 2.195834159851074
# val loss 2.753666639328003
# ______________
# epoch 90 train loss 2.1683812141418457
# val loss 2.7381973266601562
# ______________
# epoch 91 train loss 2.2135393619537354
# val loss 2.723036766052246
# ______________
# epoch 92 train loss 2.096402883529663
# val loss 2.708502769470215
# ______________
# epoch 93 train loss 2.13266921043396
# val loss 2.694653034210205
# ______________
# epoch 94 train loss 2.131516695022583
# val loss 2.681501865386963
# ______________
# epoch 95 train loss 2.108449697494507
# val loss 2.6686277389526367
# ______________
# epoch 96 train loss 2.1384730339050293
# val loss 2.656496524810791
# ______________
# epoch 97 train loss 2.0485177040100098
# val loss 2.6449625492095947
# ______________
# epoch 98 train loss 2.0703258514404297
# val loss 2.6339073181152344
# ______________
# epoch 99 train loss 2.066021203994751
# val loss 2.6234419345855713
# ______________
# epoch 100 train loss 2.0762295722961426
# val loss 2.613281011581421
# ______________
# epoch 101 train loss 2.067645788192749
# val loss 2.6037492752075195
# ______________
# epoch 102 train loss 2.029522657394409
# val loss 2.594792604446411
# ______________
# epoch 103 train loss 2.0396275520324707
# val loss 2.585832357406616
# ______________
# epoch 104 train loss 1.974968671798706
# val loss 2.576547145843506
# ______________
# epoch 105 train loss 2.0101287364959717
# val loss 2.567089557647705
# ______________
# epoch 106 train loss 1.9662916660308838
# val loss 2.557722806930542
# ______________
# epoch 107 train loss 1.9708058834075928
# val loss 2.548135995864868
# ______________
# epoch 108 train loss 1.9384851455688477
# val loss 2.5380640029907227
# ______________
# epoch 109 train loss 1.931792974472046
# val loss 2.5281875133514404
# ______________
# epoch 110 train loss 1.9543131589889526
# val loss 2.5185060501098633
# ______________
# epoch 111 train loss 1.9031983613967896
# val loss 2.5094523429870605
# ______________
# epoch 112 train loss 1.9226182699203491
# val loss 2.500915050506592
# ______________
# epoch 113 train loss 1.9000120162963867
# val loss 2.493039846420288
# ______________
# epoch 114 train loss 1.9530097246170044
# val loss 2.4857616424560547
# ______________
# epoch 115 train loss 1.863186240196228
# val loss 2.4787819385528564
# ______________
# epoch 116 train loss 1.8908538818359375
# val loss 2.47210955619812
# ______________
# epoch 117 train loss 1.8609235286712646
# val loss 2.465716600418091
# ______________
# epoch 118 train loss 1.8190964460372925
# val loss 2.459789276123047
# ______________
# epoch 119 train loss 1.813546895980835
# val loss 2.454364061355591
# ______________
# epoch 120 train loss 1.8488892316818237
# val loss 2.4493608474731445
# ______________
# epoch 121 train loss 1.8357858657836914
# val loss 2.4449615478515625
# ______________
# epoch 122 train loss 1.8075335025787354
# val loss 2.440873384475708
# ______________
# epoch 123 train loss 1.7975772619247437
# val loss 2.4362213611602783
# ______________
# epoch 124 train loss 1.839146614074707
# val loss 2.4322798252105713
# ______________
# epoch 125 train loss 1.7531510591506958
# val loss 2.4282712936401367
# ______________
# epoch 126 train loss 1.7820391654968262
# val loss 2.4244821071624756
# ______________
# epoch 127 train loss 1.8189506530761719
# val loss 2.4203691482543945
# ______________
# epoch 128 train loss 1.743078351020813
# val loss 2.4162425994873047
# ______________
# epoch 129 train loss 1.7822633981704712
# val loss 2.4129245281219482
# ______________
# epoch 130 train loss 1.7263967990875244
# val loss 2.409684419631958
# ______________
# epoch 131 train loss 1.7732714414596558
# val loss 2.4063968658447266
# ______________
# epoch 132 train loss 1.7599241733551025
# val loss 2.4029428958892822
# ______________
# epoch 133 train loss 1.7272647619247437
# val loss 2.3995840549468994
# ______________
# epoch 134 train loss 1.7444566488265991
# val loss 2.3960459232330322
# ______________
# epoch 135 train loss 1.7490355968475342
# val loss 2.392622470855713
# ______________
# epoch 136 train loss 1.716491937637329
# val loss 2.3884520530700684
# ______________
# epoch 137 train loss 1.7083311080932617
# val loss 2.3845605850219727
# ______________
# epoch 138 train loss 1.7163571119308472
# val loss 2.3808400630950928
# ______________
# epoch 139 train loss 1.6909639835357666
# val loss 2.3769326210021973
# ______________
# epoch 140 train loss 1.6909123659133911
# val loss 2.3725805282592773
# ______________
# epoch 141 train loss 1.6539438962936401
# val loss 2.368659734725952
# ______________
# epoch 142 train loss 1.653620719909668
# val loss 2.3644466400146484
# ______________
# epoch 143 train loss 1.660958170890808
# val loss 2.3610939979553223
# ______________
# epoch 144 train loss 1.6667613983154297
# val loss 2.358072280883789
# ______________
# epoch 145 train loss 1.6322834491729736
# val loss 2.3554365634918213
# ______________
# epoch 146 train loss 1.6396267414093018
# val loss 2.353102445602417
# ______________
# epoch 147 train loss 1.6120147705078125
# val loss 2.350503444671631
# ______________
# epoch 148 train loss 1.644123911857605
# val loss 2.3482773303985596
# ______________
# epoch 149 train loss 1.6669827699661255
# val loss 2.346623182296753
# ______________
# epoch 150 train loss 1.5988085269927979
# val loss 2.345186471939087
# ______________
# epoch 151 train loss 1.6346721649169922
# val loss 2.3438034057617188
# ______________
# epoch 152 train loss 1.6532505750656128
# val loss 2.342599630355835
# ______________
# epoch 153 train loss 1.637651801109314
# val loss 2.3416242599487305
# ______________
# epoch 154 train loss 1.610044240951538
# val loss 2.3405139446258545
# ______________
# epoch 155 train loss 1.5863794088363647
# val loss 2.339374542236328
# ______________
# epoch 156 train loss 1.6058679819107056
# val loss 2.3382935523986816
# ______________
# epoch 157 train loss 1.6429789066314697
# val loss 2.3375723361968994
# ______________
# epoch 158 train loss 1.5647735595703125
# val loss 2.3367233276367188
# ______________
# epoch 159 train loss 1.5439517498016357
# val loss 2.33569073677063
# ______________
# epoch 160 train loss 1.5564849376678467
# val loss 2.334678888320923
# ______________
# epoch 161 train loss 1.497815728187561
# val loss 2.332980155944824
# ______________
# epoch 162 train loss 1.6360054016113281
# val loss 2.3317008018493652
# ______________
# epoch 163 train loss 1.583269715309143
# val loss 2.330505609512329
# ______________
# epoch 164 train loss 1.539162278175354
# val loss 2.3291409015655518
# ______________
# epoch 165 train loss 1.5650439262390137
# val loss 2.3272173404693604
# ______________
# epoch 166 train loss 1.5269594192504883
# val loss 2.3251724243164062
# ______________
# epoch 167 train loss 1.5412170886993408
# val loss 2.3230485916137695
# ______________
# epoch 168 train loss 1.4862582683563232
# val loss 2.3208231925964355
# ______________
# epoch 169 train loss 1.478954792022705
# val loss 2.3191120624542236
# ______________
# epoch 170 train loss 1.531813383102417
# val loss 2.317723512649536
# ______________
# epoch 171 train loss 1.524855375289917
# val loss 2.316267251968384
# ______________
# epoch 172 train loss 1.4825574159622192
# val loss 2.3149912357330322
# ______________
# epoch 173 train loss 1.4825806617736816
# val loss 2.314069986343384
# ______________
# epoch 174 train loss 1.4642529487609863
# val loss 2.3128764629364014
# ______________
# epoch 175 train loss 1.4940229654312134
# val loss 2.312319278717041
# ______________
# epoch 176 train loss 1.4719706773757935
# val loss 2.3122315406799316
# ______________
# epoch 177 train loss 1.5164374113082886
# val loss 2.312352180480957
# ______________
# epoch 178 train loss 1.502659797668457
# val loss 2.3127617835998535
# ______________
# epoch 179 train loss 1.5421236753463745
# val loss 2.313657760620117
# ______________
# epoch 180 train loss 1.4839426279067993
# val loss 2.3146350383758545
# ______________
# epoch 181 train loss 1.5179455280303955
# val loss 2.315922737121582
# ______________
# epoch 182 train loss 1.4656599760055542
# val loss 2.317383050918579
# ______________
# epoch 183 train loss 1.4820842742919922
# val loss 2.318643808364868
# ______________
# epoch 184 train loss 1.452399492263794
# val loss 2.3197147846221924
# ______________
# epoch 185 train loss 1.4660214185714722
# val loss 2.3199257850646973
# ______________
# epoch 186 train loss 1.4211481809616089
# val loss 2.3195879459381104
# ______________
# epoch 187 train loss 1.4559199810028076
# val loss 2.3186874389648438
# ______________
# best loss 2.3122315406799316 {'pd': {'accuracy': 0.5017605633802816, 'roc_micro': 0.6798756798756799, 'roc_macro': 0.627723385537347}, 'nd': {'accuracy': 0.6142893465547927, 'roc_micro': 0.7360355693689027, 'roc_macro': 0.6966503992901508}, 'mod': {'accuracy': 0.6142893465547927, 'roc_micro': 0.7360355693689027, 'roc_macro': 0.6966503992901508}, 'dlts': {'accuracy': [0.3333333333333333, 0.3333333333333333, 0.5, 0.5, 0.5, 0.3214285714285714, 0.25, 0.3333333333333333], 'accuracy_mean': 0.3839285714285714, 'auc': [0.5, 0.5, 0.5, 0.5, 0.5, 0.65, 0.5, 0.5], 'auc_mean': 0.51875}}
# OutcomeSimulator(
#   (input_dropout): Dropout(p=0.1, inplace=False)
#   (layers): ModuleList(
#     (0): Linear(in_features=62, out_features=1000, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=1000, out_features=1000, bias=True)
#     (3): ReLU()
#   )
#   (batchnorm): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (softmax): LogSoftmax(dim=1)
#   (disease_layer): Linear(in_features=1000, out_features=3, bias=True)
#   (nodal_disease_layer): Linear(in_features=1000, out_features=3, bias=True)
#   (dlt_layers): ModuleList(
#     (0): Linear(in_features=1000, out_features=5, bias=True)
#     (1): Linear(in_features=1000, out_features=5, bias=True)
#     (2): Linear(in_features=1000, out_features=5, bias=True)
#     (3): Linear(in_features=1000, out_features=5, bias=True)
#     (4): Linear(in_features=1000, out_features=5, bias=True)
#     (5): Linear(in_features=1000, out_features=5, bias=True)
#     (6): Linear(in_features=1000, out_features=5, bias=True)
#     (7): Linear(in_features=1000, out_features=5, bias=True)
#   )
#   (treatment_layer): Linear(in_features=1000, out_features=7, bias=True)
# )

# %%
model2 = train_state(state=2)
model2
# Out:
# /tmp/ipykernel_2197865/1992661605.py:2: DtypeWarning: Columns (55) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# /tmp/ipykernel_2197865/1521532340.py:4: DtypeWarning: Columns (55) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(data_file)
# /tmp/ipykernel_2197865/1521532340.py:19: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   self.means = self.processed_df.mean(axis=0)
# /tmp/ipykernel_2197865/1521532340.py:20: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   self.stds = self.processed_df.std(axis=0)
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# epoch 0 train loss 10.293455123901367
# val loss 9.65517807006836
# ______________
# epoch 1 train loss 9.782721519470215
# val loss 9.158468246459961
# ______________
# epoch 2 train loss 9.307807922363281
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# val loss 8.710000038146973
# ______________
# epoch 3 train loss 8.863341331481934
# val loss 8.289332389831543
# ______________
# epoch 4 train loss 8.45036506652832
# val loss 7.890841484069824
# ______________
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# epoch 5 train loss 8.046409606933594
# val loss 7.511332035064697
# ______________
# epoch 6 train loss 7.64516544342041
# val loss 7.147595405578613
# ______________
# epoch 7 train loss 7.31526517868042
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# val loss 6.799703121185303
# ______________
# epoch 8 train loss 6.922632217407227
# val loss 6.468106269836426
# ______________
# epoch 9 train loss 6.586355209350586
# val loss 6.153602123260498
# ______________
# epoch 10 train loss 6.281045436859131
# val loss 5.857736587524414
# ______________
# epoch 11 train loss 6.003660678863525
# val loss 5.580427169799805
# ______________
# epoch 12 train loss 5.702635288238525
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# val loss 5.322508335113525
# ______________
# epoch 13 train loss 5.484636306762695
# val loss 5.085526943206787
# ______________
# epoch 14 train loss 5.243514537811279
# val loss 4.869521141052246
# ______________
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# epoch 15 train loss 5.022521495819092
# val loss 4.674798965454102
# ______________
# epoch 16 train loss 4.837058067321777
# val loss 4.501087188720703
# ______________
# epoch 17 train loss 4.636934280395508
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# val loss 4.347265243530273
# ______________
# epoch 18 train loss 4.503328800201416
# val loss 4.212705612182617
# ______________
# epoch 19 train loss 4.333676338195801
# val loss 4.095096111297607
# ______________
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# epoch 20 train loss 4.257548809051514
# val loss 3.9918432235717773
# ______________
# epoch 21 train loss 4.153221130371094
# val loss 3.9024770259857178
# ______________
# epoch 22 train loss 4.092041969299316
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# val loss 3.8250410556793213
# ______________
# epoch 23 train loss 4.03037166595459
# val loss 3.7579050064086914
# ______________
# epoch 24 train loss 3.9390017986297607
# val loss 3.6987476348876953
# ______________
# epoch 25 train loss 3.9231300354003906
# val loss 3.647230863571167
# ______________
# epoch 26 train loss 3.8656165599823
# val loss 3.6015827655792236
# ______________
# epoch 27 train loss 3.803894519805908
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# val loss 3.5606184005737305
# ______________
# epoch 28 train loss 3.780531167984009
# val loss 3.5240886211395264
# ______________
# epoch 29 train loss 3.740468978881836
# val loss 3.492593288421631
# ______________
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# epoch 30 train loss 3.71014142036438
# val loss 3.4643454551696777
# ______________
# epoch 31 train loss 3.6975150108337402
# val loss 3.437966823577881
# ______________
# epoch 32 train loss 3.6622302532196045
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# val loss 3.414724111557007
# ______________
# epoch 33 train loss 3.6114768981933594
# val loss 3.393545627593994
# ______________
# epoch 34 train loss 3.6216704845428467
# val loss 3.3754544258117676
# ______________
# epoch 35 train loss 3.5745790004730225
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# ...
# val loss 2.940115451812744
# ______________
# epoch 117 train loss 2.534360647201538
# val loss 2.9402432441711426
# ______________
# epoch 118 train loss 2.4976305961608887
# val loss 2.9414355754852295
# ______________
# epoch 119 train loss 2.4785401821136475
# val loss 2.943080186843872
# ______________
# epoch 120 train loss 2.477588415145874
# val loss 2.9452521800994873
# ______________
# epoch 121 train loss 2.5029568672180176
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# val loss 2.9485318660736084
# ______________
# epoch 122 train loss 2.514151096343994
# val loss 2.952755928039551
# ______________
# epoch 123 train loss 2.4670259952545166
# val loss 2.9557721614837646
# ______________
# epoch 124 train loss 2.447359800338745
# val loss 2.9573276042938232
# ______________
# epoch 125 train loss 2.4992177486419678
# val loss 2.958098888397217
# ______________
# epoch 126 train loss 2.4381864070892334
# val loss 2.95611310005188
# ______________
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# epoch 127 train loss 2.4426982402801514
# val loss 2.9522035121917725
# ______________
# best loss 2.940115451812744 {'pd': {'accuracy': 0.4965034965034965, 'roc_micro': 0.9470455780728317, 'roc_macro': -1}, 'nd': {'accuracy': 0.36074629977069, 'roc_micro': 0.7678779408339157, 'roc_macro': 0.6578843865490452}, 'mod': {'accuracy': 0.36074629977069, 'roc_micro': 0.7678779408339157, 'roc_macro': 0.6578843865490452}, 'dlts': {'accuracy': [0.5, 0.5, 0.5, 0.5, 1.0, 0.5, 0.5, 1.0], 'accuracy_mean': 0.625, 'auc': [0.5, 0.5, 0.5, 0.5, -1, 0.5, 0.5, -1], 'auc_mean': 0.125}}
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# OutcomeSimulator(
#   (input_dropout): Dropout(p=0.1, inplace=False)
#   (layers): ModuleList(
#     (0): Linear(in_features=84, out_features=1000, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=1000, out_features=1000, bias=True)
#     (3): ReLU()
#   )
#   (batchnorm): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (softmax): LogSoftmax(dim=1)
#   (disease_layer): Linear(in_features=1000, out_features=3, bias=True)
#   (nodal_disease_layer): Linear(in_features=1000, out_features=3, bias=True)
#   (dlt_layers): ModuleList(
#     (0): Linear(in_features=1000, out_features=2, bias=True)
#     (1): Linear(in_features=1000, out_features=2, bias=True)
#     (2): Linear(in_features=1000, out_features=2, bias=True)
#     (3): Linear(in_features=1000, out_features=2, bias=True)
#     (4): Linear(in_features=1000, out_features=2, bias=True)
#     (5): Linear(in_features=1000, out_features=2, bias=True)
#     (6): Linear(in_features=1000, out_features=2, bias=True)
#     (7): Linear(in_features=1000, out_features=2, bias=True)
#   )
#   (treatment_layer): Linear(in_features=1000, out_features=4, bias=True)
# )

# %%
model3 = train_state(state=3,epochs=10000)
model3
# Out:
# /tmp/ipykernel_2197865/1992661605.py:2: DtypeWarning: Columns (55) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# /tmp/ipykernel_2197865/3640945844.py:4: DtypeWarning: Columns (55) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(data_file)
# /tmp/ipykernel_2197865/3640945844.py:19: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   self.means = self.processed_df.mean(axis=0)
# /tmp/ipykernel_2197865/3640945844.py:20: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   self.stds = self.processed_df.std(axis=0)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# epoch 0 train loss 2.3138389587402344
# val loss 2.3254008293151855
# ______________
# epoch 1 train loss 2.2648849487304688
# val loss 2.3067712783813477
# ______________
# epoch 2 train loss 2.2846479415893555
# val loss 2.2883477210998535
# ______________
# epoch 3 train loss 2.2376184463500977
# val loss 2.270181655883789
# ______________
# epoch 4 train loss 2.2275636196136475
# val loss 2.2522149085998535
# ______________
# epoch 5 train loss 2.221078395843506
# val loss 2.2344324588775635
# ______________
# epoch 6 train loss 2.216287851333618
# val loss 2.216783285140991
# ______________
# epoch 7 train loss 2.2074155807495117
# val loss 2.1993064880371094
# ______________
# epoch 8 train loss 2.1488592624664307
# val loss 2.1820626258850098
# ______________
# epoch 9 train loss 2.1470835208892822
# val loss 2.1650257110595703
# ______________
# epoch 10 train loss 2.1501240730285645
# val loss 2.1481878757476807
# ______________
# epoch 11 train loss 2.137922763824463
# val loss 2.131537914276123
# ______________
# epoch 12 train loss 2.1240434646606445
# val loss 2.115100622177124
# ______________
# epoch 13 train loss 2.1244654655456543
# val loss 2.0988528728485107
# ______________
# epoch 14 train loss 2.073453426361084
# val loss 2.082836151123047
# ______________
# epoch 15 train loss 2.077018976211548
# val loss 2.0669963359832764
# ______________
# epoch 16 train loss 2.0620126724243164
# val loss 2.0513529777526855
# ______________
# epoch 17 train loss 2.054682731628418
# val loss 2.035921573638916
# ______________
# epoch 18 train loss 2.0573275089263916
# val loss 2.0207111835479736
# ______________
# epoch 19 train loss 2.0305464267730713
# val loss 2.005739688873291
# ______________
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# epoch 20 train loss 2.040351629257202
# val loss 1.9909754991531372
# ______________
# epoch 21 train loss 2.0013961791992188
# val loss 1.9764244556427002
# ______________
# epoch 22 train loss 1.9875147342681885
# val loss 1.9620957374572754
# ______________
# epoch 23 train loss 1.984541893005371
# val loss 1.9479429721832275
# ______________
# epoch 24 train loss 1.9855475425720215
# val loss 1.933992624282837
# ______________
# epoch 25 train loss 1.958439588546753
# val loss 1.9202615022659302
# ______________
# epoch 26 train loss 1.9690427780151367
# val loss 1.9067528247833252
# ______________
# epoch 27 train loss 1.9433566331863403
# val loss 1.893425703048706
# ______________
# epoch 28 train loss 1.9230029582977295
# val loss 1.8803192377090454
# ______________
# epoch 29 train loss 1.9223618507385254
# val loss 1.8674002885818481
# ______________
# epoch 30 train loss 1.9319772720336914
# val loss 1.854687213897705
# ______________
# epoch 31 train loss 1.8874354362487793
# val loss 1.8421554565429688
# ______________
# epoch 32 train loss 1.9035699367523193
# val loss 1.829838514328003
# ______________
# epoch 33 train loss 1.902966022491455
# val loss 1.8177237510681152
# ______________
# epoch 34 train loss 1.8721041679382324
# val loss 1.8057973384857178
# ______________
# epoch 35 train loss 1.8595718145370483
# val loss 1.7940620183944702
# ______________
# epoch 36 train loss 1.8672716617584229
# val loss 1.7825156450271606
# ______________
# epoch 37 train loss 1.8550186157226562
# val loss 1.7711753845214844
# ______________
# epoch 38 train loss 1.8475340604782104
# val loss 1.7599995136260986
# ______________
# epoch 39 train loss 1.8248298168182373
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# val loss 1.7489948272705078
# ______________
# epoch 40 train loss 1.8412671089172363
# val loss 1.7381744384765625
# ______________
# epoch 41 train loss 1.8092098236083984
# val loss 1.7275288105010986
# ______________
# epoch 42 train loss 1.8266572952270508
# val loss 1.717090368270874
# ______________
# epoch 43 train loss 1.8027663230895996
# val loss 1.706818699836731
# ______________
# epoch 44 train loss 1.7944339513778687
# val loss 1.6967370510101318
# ______________
# epoch 45 train loss 1.7714426517486572
# val loss 1.6868512630462646
# ______________
# epoch 46 train loss 1.7813191413879395
# val loss 1.677131175994873
# ______________
# epoch 47 train loss 1.7748090028762817
# val loss 1.6675701141357422
# ______________
# epoch 48 train loss 1.7735224962234497
# val loss 1.6581759452819824
# ______________
# epoch 49 train loss 1.7350866794586182
# val loss 1.6489367485046387
# ______________
# epoch 50 train loss 1.7510061264038086
# val loss 1.6398577690124512
# ______________
# epoch 51 train loss 1.7218761444091797
# val loss 1.6309609413146973
# ______________
# epoch 52 train loss 1.7375764846801758
# val loss 1.6222000122070312
# ______________
# epoch 53 train loss 1.7239735126495361
# val loss 1.6135685443878174
# ______________
# epoch 54 train loss 1.7374120950698853
# val loss 1.6050853729248047
# ______________
# epoch 55 train loss 1.707783818244934
# val loss 1.5967576503753662
# ______________
# epoch 56 train loss 1.7081923484802246
# val loss 1.5885798931121826
# ______________
# epoch 57 train loss 1.6820943355560303
# val loss 1.5805442333221436
# ______________
# epoch 58 train loss 1.712123990058899
# val loss 1.5726661682128906
# ______________
# epoch 59 train loss 1.6779186725616455
# val loss 1.5649077892303467
# ______________
# epoch 60 train loss 1.6843445301055908
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# ...
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# val loss 1.0501489639282227
# ______________
# epoch 404 train loss 1.073700189590454
# val loss 1.0500068664550781
# ______________
# epoch 405 train loss 1.0577805042266846
# val loss 1.0498464107513428
# ______________
# epoch 406 train loss 1.0707736015319824
# val loss 1.0496172904968262
# ______________
# epoch 407 train loss 1.0631049871444702
# val loss 1.049409031867981
# ______________
# epoch 408 train loss 1.0710766315460205
# val loss 1.0491899251937866
# ______________
# epoch 409 train loss 1.0722688436508179
# val loss 1.0489970445632935
# ______________
# epoch 410 train loss 1.0422978401184082
# val loss 1.048844814300537
# ______________
# epoch 411 train loss 1.0368566513061523
# val loss 1.0486669540405273
# ______________
# epoch 412 train loss 1.0583981275558472
# val loss 1.0484602451324463
# ______________
# epoch 413 train loss 1.0293054580688477
# val loss 1.0482161045074463
# ______________
# epoch 414 train loss 1.034493327140808
# val loss 1.047980785369873
# ______________
# epoch 415 train loss 1.0457481145858765
# val loss 1.0478241443634033
# ______________
# epoch 416 train loss 1.0726507902145386
# val loss 1.0476744174957275
# ______________
# epoch 417 train loss 1.0484263896942139
# val loss 1.0475819110870361
# ______________
# epoch 418 train loss 1.0261338949203491
# val loss 1.0474803447723389
# ______________
# epoch 419 train loss 1.056445837020874
# val loss 1.047400712966919
# ______________
# epoch 420 train loss 1.0347068309783936
# val loss 1.0473564863204956
# ______________
# epoch 421 train loss 1.0580646991729736
# val loss 1.0473074913024902
# ______________
# epoch 422 train loss 1.0594236850738525
# val loss 1.0472519397735596
# ______________
# epoch 423 train loss 1.0459511280059814
# val loss 1.0472331047058105
# ______________
# epoch 424 train loss 1.0332573652267456
# val loss 1.047231912612915
# ______________
# epoch 425 train loss 1.0536006689071655
# val loss 1.0472203493118286
# ______________
# epoch 426 train loss 1.0424549579620361
# val loss 1.0471967458724976
# ______________
# epoch 427 train loss 1.0770846605300903
# val loss 1.047239899635315
# ______________
# epoch 428 train loss 1.025565266609192
# val loss 1.0472596883773804
# ______________
# epoch 429 train loss 1.0439645051956177
# val loss 1.0472973585128784
# ______________
# epoch 430 train loss 1.029745101928711
# val loss 1.0473549365997314
# ______________
# epoch 431 train loss 1.0482871532440186
# val loss 1.0474272966384888
# ______________
# epoch 432 train loss 1.0025814771652222
# val loss 1.0474755764007568
# ______________
# epoch 433 train loss 1.0569725036621094
# val loss 1.047553539276123
# ______________
# epoch 434 train loss 1.0278716087341309
# val loss 1.0475717782974243
# ______________
# epoch 435 train loss 1.0423078536987305
# val loss 1.0475993156433105
# ______________
# epoch 436 train loss 1.01643705368042
# val loss 1.0475631952285767
# ______________
# epoch 437 train loss 1.0186678171157837
# val loss 1.047475814819336
# ______________
# best loss 1.0471967458724976 {'Overall Survival (4 Years)': {'accuracy': -1, 'mse': 0.06785117, 'auc': -1}, 'FT': {'accuracy': -1, 'mse': 0.10796758, 'auc': 0.712008895478132}, 'Aspiration rate Post-therapy': {'accuracy': -1, 'mse': 0.1258901, 'auc': 0.6953371140516699}}
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/label.py:622: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = np.zeros((len(y), 1), dtype=np.int)
# EndpointSimulator(
#   (input_dropout): Dropout(p=0.1, inplace=False)
#   (layers): ModuleList(
#     (0): Linear(in_features=82, out_features=500, bias=True)
#     (1): ReLU()
#   )
#   (batchnorm): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (softmax): LogSoftmax(dim=1)
#   (outcome_layer): Linear(in_features=500, out_features=3, bias=True)
#   (sigmoid): Sigmoid()
# )

# %%
def breakup_state_models(state_model):
    #for state 1 and 2
    models = {}
    models['pd'] = lambda x: state_model(x)[0]
    models['nd'] = lambda x: state_model(x)[1]
    models['chemo'] = lambda x: state_model(x)[2]
    for i,dlt in enumerate(Const.dlt1):
        models[dlt] = lambda x: state_model(x)[3][:,i]
    return models

def breakup_outcome_models(omodel):
    models = {}
    for i,name in enumerate(Const.outcomes):
        models[name] = lambda x: omodel(x)[:,i].reshape(-1,1)
    return models

def get_all_models(m1,m2,m3):
    state1_models = breakup_state_models(m1)
    state2_models = breakup_state_models(m2)
    state3_models = breakup_outcome_models(m3)
    all_models = {}
    for i,sm in enumerate([state1_models,state2_models,state3_models]):
        for ii,m in sm.items():
            all_models[ii +  '_state' + str(i+1)] = m
    return all_models

all_models = get_all_models(model,model2,model3)
all_models
# Out:
# {'pd_state1': <function __main__.breakup_state_models.<locals>.<lambda>(x)>,
#  'nd_state1': <function __main__.breakup_state_models.<locals>.<lambda>(x)>,
#  'chemo_state1': <function __main__.breakup_state_models.<locals>.<lambda>(x)>,
#  'DLT_Hematological_state1': <function __main__.breakup_state_models.<locals>.<lambda>(x)>,
#  'DLT_Gastrointestinal_state1': <function __main__.breakup_state_models.<locals>.<lambda>(x)>,
#  'DLT_Nephrological_state1': <function __main__.breakup_state_models.<locals>.<lambda>(x)>,
#  'DLT_Other_state1': <function __main__.breakup_state_models.<locals>.<lambda>(x)>,
#  'DLT_Infection (Pneumonia)_state1': <function __main__.breakup_state_models.<locals>.<lambda>(x)>,
#  'DLT_Dermatological_state1': <function __main__.breakup_state_models.<locals>.<lambda>(x)>,
#  'DLT_Neurological_state1': <function __main__.breakup_state_models.<locals>.<lambda>(x)>,
#  'DLT_Vascular_state1': <function __main__.breakup_state_models.<locals>.<lambda>(x)>,
#  'pd_state2': <function __main__.breakup_state_models.<locals>.<lambda>(x)>,
#  'nd_state2': <function __main__.breakup_state_models.<locals>.<lambda>(x)>,
#  'chemo_state2': <function __main__.breakup_state_models.<locals>.<lambda>(x)>,
#  'DLT_Hematological_state2': <function __main__.breakup_state_models.<locals>.<lambda>(x)>,
#  'DLT_Gastrointestinal_state2': <function __main__.breakup_state_models.<locals>.<lambda>(x)>,
#  'DLT_Nephrological_state2': <function __main__.breakup_state_models.<locals>.<lambda>(x)>,
#  'DLT_Other_state2': <function __main__.breakup_state_models.<locals>.<lambda>(x)>,
#  'DLT_Infection (Pneumonia)_state2': <function __main__.breakup_state_models.<locals>.<lambda>(x)>,
#  'DLT_Dermatological_state2': <function __main__.breakup_state_models.<locals>.<lambda>(x)>,
#  'DLT_Neurological_state2': <function __main__.breakup_state_models.<locals>.<lambda>(x)>,
#  'DLT_Vascular_state2': <function __main__.breakup_state_models.<locals>.<lambda>(x)>,
#  'Overall Survival (4 Years)_state3': <function __main__.breakup_outcome_models.<locals>.<lambda>(x)>,
#  'FT_state3': <function __main__.breakup_outcome_models.<locals>.<lambda>(x)>,
#  'Aspiration rate Post-therapy_state3': <function __main__.breakup_outcome_models.<locals>.<lambda>(x)>}

# %%
Const.dlt2
# Out:
# ['DLT_Hematological 2',
#  'DLT_Gastrointestinal 2',
#  'DLT_Nephrological 2',
#  'DLT_Other 2',
#  'DLT_Infection (Pneumonia) 2',
#  'DLT_Dermatological 2',
#  'DLT_Neurological 2',
#  'DLT_Vascular 2']

# %%
from captum.attr import IntegratedGradients

key ='FT_state3'
ig = IntegratedGradients(all_models[key])
dataset = DTDataset()
xtestdf = dataset.get_input_state(step=int(key[-1]))
xtest = df_to_torch(xtestdf)
all_models[key](xtest).shape
# attributions = ig.attribute(xtest,torch.zeros(xtest.shape),target=1)
# test = pd.DataFrame(attributions,columns = xtestdf.columns, index=xtestdf.index)
# test.describe().T
# Out:
# /tmp/ipykernel_2197865/3640945844.py:4: DtypeWarning: Columns (55) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(data_file)
# /tmp/ipykernel_2197865/3640945844.py:19: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   self.means = self.processed_df.mean(axis=0)
# /tmp/ipykernel_2197865/3640945844.py:20: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   self.stds = self.processed_df.std(axis=0)
# torch.Size([536, 1])

# %%
dataset.get_intermediate_outcomes(step=3)
# Out:
# [id
#  3        0
#  5        0
#  6        0
#  7        0
#  8        0
#          ..
#  10201    0
#  10202    0
#  10203    0
#  10204    0
#  10205    0
#  Name: Decision 1 (Induction Chemo) Y/N, Length: 536, dtype: int64,
#  id
#  3        1
#  5        1
#  6        1
#  7        0
#  8        0
#          ..
#  10201    1
#  10202    1
#  10203    0
#  10204    1
#  10205    1
#  Name: Decision 2 (CC / RT alone), Length: 536, dtype: int64,
#  id
#  3        0
#  5        0
#  6        0
#  7        0
#  8        0
#          ..
#  10201    0
#  10202    1
#  10203    1
#  10204    0
#  10205    1
#  Name: Decision 3 Neck Dissection (Y/N), Length: 536, dtype: int64]

# %%
def get_ytrue(name,df):
    outcomes=None
    value = None
    if name == 'pd_state1':
        outcomes = df[Const.primary_disease_states]
    elif name == 'pd_state2':
        outcomes = df[Const.primary_disease_states2]
    elif name == 'nd_state1':
        outcomes = df[Const.nodal_disease_states]
    elif name == 'nd_state2':
        outcomes = df[Const.nodal_disease_states2]
    elif name == 'chemo_state1':
        outcomes = df[Const.modifications]
    elif name == 'chemo_state2':
        outcomes = df[Const.ccs]   
    if outcomes is not None:
        value = outcomes.idxmax(axis=1)
    if 'DLT' in name:
        newname = name.replace('_state', ' ').replace('1','').strip()
        value = df[newname]
    if name.replace('_state3','') in Const.outcomes:
        value = df[name.replace('_state3','')]
    if value is None:
        print(name,df.columns)
    return value

def check_impact_of_decisions(model_dict,data):
    results = []
    #todo: this is wrong fix it
    ids = []
    df = data.get_data()
    outcomedict = {step: pd.concat(data.get_intermediate_outcomes(step=step),axis=1) for step in [1,2,3]}
    for decision in Const.decisions:
        for name, model in model_dict.items():
            step = int(name[-1])
            subset0 = dataset.get_input_state(step=step,fixed={decision: 0})
            subset1 = dataset.get_input_state(step=step,fixed={decision: 1})
            outcomes = outcomedict[step]
            ids = subset0.index.values
            x0 = df_to_torch(subset0)
            x1 = df_to_torch(subset1)
            y0 = model(x0).detach().cpu().numpy()
            y1 = model(x1).detach().cpu().numpy()
            original = data.get_input_state(step=step)
            xx = df_to_torch(original)
            yy = model(xx).detach().cpu().numpy()
            ytrue = get_ytrue(name,outcomes)
            if "DLT" in name:
                y0 = y0.argmax(axis=1).reshape(-1,1)
                y1 = y1.argmax(axis=1).reshape(-1,1)
                yy = yy.argmax(axis=1).reshape(-1,1)
                change = y0 - y1
                decision_change = (y0 != y1).astype(int)
            elif y0.shape[1] == 1:
                change = y1 - y0
                decision_change = np.abs((y0 > .5).astype(int) - (y1 > .5).astype(int))
            else:
                index = np.unravel_index(np.argmax(yy, axis=1), yy.shape)
                change = (y0[index] - y1[index]).reshape(-1,1)
                decision_change =  (y0.argmax(axis=1).reshape(-1,1) != y1.argmax(axis=1).reshape(-1,1)).astype(int)
                yy = yy.argmax(axis=1).reshape(-1,1)
                y1 = y1.argmax(axis=1).reshape(-1,1)
                y0 = y0.argmax(axis=1).reshape(-1,1)
            outcome = name.replace('_state','')
            for ii,pid in enumerate(ids):
                oo = ytrue.loc[pid]
                onew = y0[ii][0]
                original_decision = df.loc[pid,decision]
                if original_decision > 0:
                    onew = y0[ii][0]
                oname = Const.name_dict.get(name)
                if oname is not None:
                    onew = oname[onew]
                entry = {'id': pid, 'decision': decision,'outcome': outcome,'original_choice': original_decision, 'original_result': oo, 'alt_result': onew, 'change': change[ii][0], 'decision_change': decision_change[ii][0]}
                results.append(entry)
    return pd.DataFrame(results)

test = check_impact_of_decisions(all_models,dataset)
test
# Out:
#           id                          decision                        outcome  \
# 0          3  Decision 1 (Induction Chemo) Y/N                            pd1
# 1          5  Decision 1 (Induction Chemo) Y/N                            pd1
# 2          6  Decision 1 (Induction Chemo) Y/N                            pd1
# 3          7  Decision 1 (Induction Chemo) Y/N                            pd1
# 4          8  Decision 1 (Induction Chemo) Y/N                            pd1
# ...      ...                               ...                            ...
# 40195  10201  Decision 3 Neck Dissection (Y/N)  Aspiration rate Post-therapy3
# 40196  10202  Decision 3 Neck Dissection (Y/N)  Aspiration rate Post-therapy3
# 40197  10203  Decision 3 Neck Dissection (Y/N)  Aspiration rate Post-therapy3
# 40198  10204  Decision 3 Neck Dissection (Y/N)  Aspiration rate Post-therapy3
# 40199  10205  Decision 3 Neck Dissection (Y/N)  Aspiration rate Post-therapy3
#
#        original_choice original_result  alt_result    change  decision_change
# 0                    0      CR Primary  CR Primary  0.156656                0
# 1                    0      CR Primary  CR Primary  0.156656                0
# 2                    0      CR Primary  CR Primary  0.156656                1
# 3                    0      CR Primary  CR Primary  0.156656                0
# 4                    0      CR Primary  CR Primary  0.156656                0
# ...                ...             ...         ...       ...              ...
# 40195                0               0     0.11513  0.083809                0
# 40196                1               0    0.505635  0.067371                0
# 40197                1               0    0.035785  0.024135                0
# 40198                0               0    0.094983  0.061406                0
# 40199                1               0    0.298355  0.139449                0
#
# [40200 rows x 8 columns]

# %%
data.get_data()['SD Primary 2'].sum()
# Out:
# 2.0

# %%
(test[test.outcome == 'pd2'].original_result == 'SD Primary 2').sum()
# Out:
# 6

# %%
check_impact_of_decisions(all_models,dataset).to_csv('../data/decision_impacts.csv')
